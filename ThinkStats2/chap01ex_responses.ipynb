# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
print '<14   ',len(df.prglngth[df.prglngth <= 13])
print '14-26 ',len(df.prglngth[(df.prglngth > 13) & (df.prglngth < 27)])
print '27+   ',len(df.prglngth[df.prglngth > 26])
# Out:
# <14    3522
# 14-26  793
# 27+    9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
first = np.sum(df.prglngth <=13)
second = np.sum((df.prglngth >13)&(df.prglngth < 27))
third = np.sum(df.prglngth >=27)

print "13 WEEKS OR LESS ", first
print "14-26 WEEKS ", second
print "27 WEEKS OR LONGER ", third
print "TOTAL ", np.sum([first, second, third])
# Out:
# 13 WEEKS OR LESS  3522
# 14-26 WEEKS  793
# 27 WEEKS OR LONGER  9278
# TOTAL  13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print '13 WEEKS OR LESS\t', len(df[df.prglngth <= 13])
print '14-26 WEEKS\t\t', len(df[(df.prglngth >= 14) & (df.prglngth <= 26)])
print '27 WEEKS OR LONGER\t', len(df[df.prglngth >= 27])
# Out:
# 13 WEEKS OR LESS	3522
# 14-26 WEEKS		793
# 27 WEEKS OR LONGER	9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# ###### Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print "0-13 wks: " + str(sum(df.prglngth <= 13))
print "14-26 wks: " + str(sum((df.prglngth >= 14) & (df.prglngth <= 26)))
print ">27 wks: " + str(sum(df.prglngth >= 27))
# Out:
# 0-13 wks: 3522
# 14-26 wks: 793
# >27 wks: 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.birthord.value_counts().sort_index()
# Out:
# 1     4413
# 2     2874
# 3     1234
# 4      421
# 5      126
# 6       50
# 7       20
# 8        7
# 9        2
# 10       1
# Name: birthord, dtype: int64

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
import numpy
print numpy.sum(df.prglngth <= 13)
print numpy.sum((df.prglngth > 13) & (df.prglngth < 27))
print numpy.sum(df.prglngth >= 27)
# Out:
# 3522
# 793
# 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
#df.prglngth.value_counts().sort_index()
value_counts = df.prglngth.value_counts()
print "0-13 weeks", len(df[(df.prglngth >= 0) & (df.prglngth <= 13)])
print "14-26 weeks", len(df[(df.prglngth >= 14) & (df.prglngth <= 26)])
print "Over 26 weeks", len(df[(df.prglngth > 26)])
print "Total Number", len(df[df.prglngth])
# Out:
# 0-13 weeks 3522
# 14-26 weeks 793
# Over 26 weeks 9278
# Total Number 13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print 'value', ' total'
print '0-13  ', sum(prglngth[0:14])
print '14-26 ', sum(prglngth[14:27])
print '27-50 ', sum(prglngth[27:50])
print 'total:', prglngth.sum()
# Out:
# value  total
# 0-13   3522
# 14-26  793
# 27-50  9278
# total: 13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
cdbk = df.prglngth.value_counts().sort_index()
thirteenorless = 0
fourteento26  = 0
twentysevenormore = 0
for i in range(0, 49):
    if i <= 13:
        thirteenorless += cdbk[i]
    elif 13 < i < 27:
        fourteento26 += cdbk[i]
    elif 27 <= i:
        twentysevenormore += cdbk[i]
        
twentysevenormore += cdbk[50]

print '13 weeks or less ', thirteenorless
print '14 to 26 weeks   ', fourteento26
print '27 weeks or more ', twentysevenormore
print 'TOTAL            ',thirteenorless + fourteento26 + twentysevenormore
# Out:
# 13 weeks or less  3522
# 14 to 26 weeks    793
# 27 weeks or more  9278
# TOTAL             13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
counts = df.prglngth.value_counts().sort_index()

# group records by pregnancy length
def prglngth_group(prg_len):
    prg_len_labels = ["0-13 WEEKS", "14-26 WEEKS", "27+ WEEKS"]

    if (prg_len < 14):
        return prg_len_labels[0]
    if (prg_len >= 14 and prg_len < 27):
        return prg_len_labels[1]
    return prg_len_labels[2]
    
# total up the number in each group
prglngth_df = counts.groupby(prglngth_group).sum()

# add additional column
prglngth_df["TOTAL"] = counts.sum()

print prglngth_df
# Out:
# 0-13 WEEKS      3522
# 14-26 WEEKS      793
# 27+ WEEKS       9278
# TOTAL          13593
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print ("13 weeks or less: " + str(len(df[df.prglngth <= 13].index)))
print ("14 - 26 weeks: " + str(len(df[(df.prglngth >= 14) & (df.prglngth <=26)].index)))
print ("27 weeks or longer: " + str(len(df[df.prglngth >= 27].index)))
# Out:
# 13 weeks or less: 3522
# 14 - 26 weeks: 793
# 27 weeks or longer: 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
lengths = df.prglngth.value_counts().sort_index()
print '13 Weeks or Less: ', lengths[:14].sum()
print '14-26 Weeks: ', lengths[14:27].sum()
print '27 Weeks or Longer: ', lengths[27:].sum()
print 'Total: ', len(df.prglngth)
# Out:
# 13 Weeks or Less:  3522
# 14-26 Weeks:  793
# 27 Weeks or Longer:  9278
# Total:  13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print "13 WEEKS OR LESS:", len(df[df.prglngth <= 13].prglngth)
print "14-26 WEEKS:", len(df[(df.prglngth >= 14) & (df.prglngth <= 26)].prglngth)
print "27 WEEKS OR LONGER:", len(df[df.prglngth >= 27].prglngth)
print "TOTAL:", len(df.prglngth)
# Out:
# 13 WEEKS OR LESS: 3522
# 14-26 WEEKS: 793
# 27 WEEKS OR LONGER: 9278
# TOTAL: 13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print "<=13  wks", len(df[df.prglngth <= 13].prglngth)
print "13-24 wks", len(df[(df.prglngth > 13) & (df.prglngth <= 26)].prglngth)
print "13-24 wks", len(df[(df.prglngth > 26)].prglngth)
# Out:
# <=13  wks 3522
# 13-24 wks 793
# 13-24 wks 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
prglength_series = df.prglngth.value_counts().sort_index()
print " VALUE " + "COUNT"
print "--------------"
print " 0-13: " + str(sum(prglength_series[0:14]))
print "14-26: " + str(sum(prglength_series[14:27]))
print "27-50: " + str(sum(prglength_series[27:]))
# Out:
#  VALUE COUNT
# --------------
#  0-13: 3522
# 14-26: 793
# 27-50: 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print "0-13 weeks       ", len(df[(df.prglngth >= 0) & (df.prglngth <=13)])
print "14-26 weeks      ", len(df[(df.prglngth >= 14) & (df.prglngth <=26)])
print "27 weeks or older", len(df[df.prglngth >= 27])
print "Total            ", df.prglngth.value_counts().sum()
# Out:
# 0-13 weeks        3522
# 14-26 weeks       793
# 27 weeks or older 9278
# Total             13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
print "0-13 weeks", len(df[(df.prglngth >= 0) & (df.prglngth <= 13)])
print "14-26 weeks", len(df[(df.prglngth >= 14) & (df.prglngth <= 26)])
print ">26 weeks", len(df[(df.prglngth > 26)])
# Out:
# 0-13 weeks 3522
# 14-26 weeks 793
# >26 weeks 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
df.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %% [markdown]
# In order to compare to the codebook, I need to sum the up to 13 weeks or less, between 14-26 weeks, and 27 weeks or longer. This summing is done directly below. After summing and comparing, these sums match the prglngth data in the codebook.

# %%
prl = df.prglngth.value_counts().sort_index()
sum(prl[0:14])
# Out:
# 3522

# %%
sum(prl[14:27])
# Out:
# 793

# %%
sum(prl[27:])
# Out:
# 9278

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
sorted_prglngth_counts = df.prglngth.value_counts().sort_index()

total_0to13 = 0
for x in sorted_prglngth_counts[0:14]:
    total_0to13 += x
print total_0to13

total_14to26 = 0
for x in sorted_prglngth_counts[14:27]:
    total_14to26 += x
print total_14to26

total_27to51 = 0
for x in sorted_prglngth_counts[27:51]:
    total_27to51 += x
print total_27to51

total_prglgnth_counts = total_0to13 + total_14to26 + total_27to51
print total_prglgnth_counts


# Potential discussion points:
# Most common, median, mean, and rarest prglength
# Potential reasons for the numbers in previous discussion point
# Out:
# 3522
# 793
# 9278
# 13593

# %% [markdown]
# ## Question 1

# %% [markdown]
# Print value counts for <tt>prglngth</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611931)

# %%
zero_to_thirteen = df.prglngth[df.prglngth <= 13].count()
fourteen_to_twentysix = df.prglngth[(df.prglngth >= 14) & (df.prglngth <= 26)].count()
twentyseven_and_up = df.prglngth[df.prglngth >= 27].count()
zero_to_thirteen, fourteen_to_twentysix, twentyseven_and_up
# Out:
# (3522, 793, 9278)

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
print '<20   ',len(df.agepreg[df.agepreg < 20])
print '20-24 ',len(df.agepreg[(df.agepreg >= 20) & (df.agepreg < 25)])
print '25-29 ',len(df.agepreg[(df.agepreg >= 25) & (df.agepreg < 30)])
print '30-44 ',len(df.agepreg[(df.agepreg >= 30) & (df.agepreg < 45)])
# Out:
# <20    3182
# 20-24  4246
# 25-29  3178
# 30-44  2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
x = df.agepreg.isnull().sum()
y = (df.agepreg<20).sum()
z = ((df.agepreg >= 20) & (df.agepreg < 25)).sum()
k = ((df.agepreg >= 25) & (df.agepreg < 30)).sum()
j = ((df.agepreg >= 30) & (df.agepreg < 45)).sum()

print "INAPPLICABLE ", x
print "UNDER 20 YEARS ", y 
print "20-24 YEARS ", z  
print "25-29 YEARS ", k
print "30-44 YEARS ", j
print "TOTAL ", np.sum([x,y,z,k,j])
# Out:
# INAPPLICABLE  352
# UNDER 20 YEARS  3182
# 20-24 YEARS  4246
# 25-29 YEARS  3178
# 30-44 YEARS  2635
# TOTAL  13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print 'INAPPLICABLE\t', len(df[np.isnan(df.agepreg)])
print 'UNDER 20 YEARS\t', len(df[df.agepreg <= 19.99])
print '20-24 YEARS\t', len(df[(df.agepreg >= 20.00) & (df.agepreg <= 24.99)])
print '25-29 YEARS\t', len(df[(df.agepreg >= 25.00) & (df.agepreg <= 29.99)])
print '30-44 YEARS\t', len(df[(df.agepreg >= 30.00) & (df.agepreg <= 44.99)])
# Out:
# INAPPLICABLE	352
# UNDER 20 YEARS	3182
# 20-24 YEARS	4246
# 25-29 YEARS	3178
# 30-44 YEARS	2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "Inapplicable: " + str(sum(df.agepreg.isnull()))
print "<20 years: " + str(sum(df.agepreg < 20))
print "20-24 years: " + str(sum((df.agepreg >= 20) & (df.agepreg < 25)))
print "25-29 years: " + str(sum((df.agepreg >= 25) & (df.agepreg < 30)))
print "30-44 years: " + str(sum((df.agepreg >= 30) & (df.agepreg < 45)))
# Out:
# Inapplicable: 352
# <20 years: 3182
# 20-24 years: 4246
# 25-29 years: 3178
# 30-44 years: 2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33    1
# 10.50    1
# 10.83    1
# 10.91    1
# 11.08    1
# 11.41    1
# 11.50    1
# 11.75    2
# 12.08    1
# 12.25    1
# 12.41    2
# 12.50    1
# 12.66    2
# 12.75    1
# 12.83    2
# ...
# 41.91    4
# 42.08    2
# 42.16    1
# 42.25    1
# 42.33    1
# 42.41    1
# 42.50    2
# 42.58    2
# 42.75    2
# 43.00    3
# 43.16    1
# 43.25    4
# 43.58    3
# 43.91    1
# 44.08    1
# Length: 373, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print df.agepreg.isnull().sum()
print (df.agepreg < 20).sum()
print ((df.agepreg >= 20) & (df.agepreg <= 24)).sum()             
print ((df.agepreg >= 25) & (df.agepreg <= 29)).sum()             
print ((df.agepreg >= 25) & (df.agepreg <= 29)).sum()               
print ((df.agepreg >= 30) & (df.agepreg <= 44)).sum()
# Out:
# 352
# 3182
# 3528
# 2697
# 2697
# 2634

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
#df.agepreg.value_counts().sort_index()
value_count = df.agepreg.value_counts()
print "15 and Under", len(df[(df.agepreg > 0) & (df.agepreg <= 15)]) #keep in mind ages are decimals, count 10.3 as 10
print "16-19 years", len(df[(df.agepreg > 15) & (df.agepreg < 20)])
print "20-24 years", len(df[(df.agepreg >= 20) & (df.agepreg < 25)])
print "25-29 years", len(df[(df.agepreg >= 25) & (df.agepreg < 30)])
print "30-44 years", len(df[(df.agepreg >= 30) & (df.agepreg < 45)])
print "Total Number", len(df.agepreg)
# Out:
#  15 and Under 173
# 16-19 years 3009
# 20-24 years 4246
# 25-29 years 3178
# 30-44 years 2635
# Total Number 13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print 'value  ', '   total'
print '.         ', str(len(df.agepreg) - len(df.agepreg[(df.agepreg >= 0) & (df.agepreg < 45)]))
print '0-1999    ', str(len(df.agepreg[(df.agepreg >= 0) & (df.agepreg < 20)]))
print '2000-2499 ', str(len(df.agepreg[(df.agepreg >= 20) & (df.agepreg < 25)]))
print '2500-2999 ', str(len(df.agepreg[(df.agepreg >= 25) & (df.agepreg < 30)]))
print '3000-4499 ', str(len(df.agepreg[(df.agepreg >= 30) & (df.agepreg < 45)]))
print 'total:    ', len(df.agepreg)
# Out:
# value      total
# .          352
# 0-1999     3182
# 2000-2499  4246
# 2500-2999  3178
# 3000-4499  2635
# total:     13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
inapplicable = len(df[np.isnan(df.agepreg)])
under20 = len(df[df.agepreg < 20])
twentyto24 = len(df[(df.agepreg >= 20) & (df.agepreg < 25)])
twentyfiveto29 = len(df[(25 <= df.agepreg) & (df.agepreg < 30)])
thirtyandup = len(df[df.agepreg >= 30])

print 'Inapplicable   ', inapplicable
print 'Under 20 years ', under20 
print '20 to 24 years ', twentyto24
print '25 to 29 years ', twentyfiveto29
print '30 and up      ', thirtyandup
print 'TOTAL          ',inapplicable + under20+twentyto24 + twentyfiveto29 + thirtyandup #doesn't include inapplicable
# Out:
# Inapplicable    352
# Under 20 years  3182
# 20 to 24 years  4246
# 25 to 29 years  3178
# 30 and up       2635
# TOTAL           13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
counts = df.agepreg.value_counts().sort_index()

# The codebook divides age at pregnancy outcome into the following groups:
agepreg_labels = [
    "0-19 YEARS",
    "20-24 YEARS",
    "25-29 YEARS",
    "30-44 YEARS"
]

# group by each age group
def agepreg_group(age):
    if (age < 20):
        return agepreg_labels[0]
    if (age >= 20 and age < 25):
        return agepreg_labels[1]
    if (age >= 25 and age < 30):
        return agepreg_labels[2]
    return agepreg_labels[3]

# total up the number in each age group
agepreg_df = counts.groupby(agepreg_group).sum()

# add additional columns
agepreg_df["INAPPLICABLE"] = sum(df.agepreg.isnull())
agepreg_df["TOTAL"] = len(df.agepreg)

print agepreg_df
# Out:
# 0-19 YEARS       3182
# 20-24 YEARS      4246
# 25-29 YEARS      3178
# 30-44 YEARS      2635
# INAPPLICABLE      352
# TOTAL           13593
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print ("Under 20 years: " + str(len(df[df.agepreg <20].index)))
print ("20 - 24 years: " + str(len(df[(df.agepreg >= 20) & (df.agepreg <25)].index)))
print ("25 - 29 years: " + str(len(df[(df.agepreg >= 25) & (df.agepreg <30)].index)))
print ("30 - 44 years: " + str(len(df[(df.agepreg >= 30) & (df.agepreg <45)].index)))
# Out:
# Under 20 years: 3182
# 20 - 24 years: 4246
# 25 - 29 years: 3178
# 30 - 44 years: 2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "Under 20: ", len(df[df.agepreg < 20])
print "20-24: ", len(df[(df.agepreg >= 20) & (df.agepreg < 25)])
print "25-29: ", len(df[(df.agepreg >= 25) & (df.agepreg < 30)])
print "30-44: ", len(df[(df.agepreg >= 30) & (df.agepreg < 45)])
print "Total: ", len(df)
# Out:
# Under 20:  3182
# 20-24:  4246
# 25-29:  3178
# 30-44:  2635
# Total:  13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "UNDER 20 YEARS:", len(df[df.agepreg < 20])
print "20-24 YEARS:", len(df[(df.agepreg >= 20) & (df.agepreg < 25)])
print "25-29 YEARS:", len(df[(df.agepreg >= 25) & (df.agepreg < 30)])
print "30-44 YEARS:", len(df[(df.agepreg >= 30) & (df.agepreg < 45)])
# Out:
# UNDER 20 YEARS: 3182
# 20-24 YEARS: 4246
# 25-29 YEARS: 3178
# 30-44 YEARS: 2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "0 to 20 --> ", len(df[df.agepreg < 20]) 
print "20 to 25 --> ",len(df[(df.agepreg >= 20) & (df.agepreg < 25)]) 
print "25 to 29 --> ",len(df[(df.agepreg >= 25) & (df.agepreg < 30)]) 
print "30 to 44 --> ",len(df[(df.agepreg >= 30) & (df.agepreg < 44)])
# Out:
# 0 to 20 -->  3182
# 20 to 25 -->  4246
# 25 to 29 -->  3178
# 30 to 44 -->  2634

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "  inapplicable: " + str(len(df.agepreg) - len(df.agepreg[df.agepreg < 45]))
print "under 20 years: " + str(len(df.agepreg[df.agepreg < 20]))
print " 20 - 24 years: " + str(len(df.agepreg[(df.agepreg >= 20) & (df.agepreg < 25)]))
print " 25 - 29 years: " + str(len(df.agepreg[(df.agepreg >= 25) & (df.agepreg < 30)]))
print "3 0 - 44 years: " + str(len(df.agepreg[(df.agepreg >= 30) & (df.agepreg < 45)]))
# Out:
#   inapplicable: 352
# under 20 years: 3182
#  20 - 24 years: 4246
#  25 - 29 years: 3178
# 3 0 - 44 years: 2635

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "Inapplicable    ", df.agepreg.isnull().sum()
print "Under 20 years  ", len(df[df.agepreg < 20.00])
print "20-24 years     ", len(df[(df.agepreg >= 20.00) & (df.agepreg <25)])
print "25-29 years     ", len(df[(df.agepreg >= 25) & (df.agepreg <30)])
print "30 years & above", len(df[df.agepreg > 30])
print "Total           ", df.agepreg.isnull().sum()+df.agepreg.value_counts().sum()
# Out:
# Inapplicable     352
# Under 20 years   3182
# 20-24 years      4246
# 25-29 years      3178
# 30 years & above 2587
# Total            13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
print "0-20 years", len(df[(df.agepreg >= 0) & (df.agepreg < 20)])
print "20-24 years", len(df[(df.agepreg >= 20) & (df.agepreg <= 24)])
print "25-29 years", len(df[(df.agepreg >= 25) & (df.agepreg <= 29)])
print "30-44 years", len(df[(df.agepreg >= 30) & (df.agepreg <= 44)])
# Out:
# 0-20 years 3182
# 20-24 years 3528
# 25-29 years 2697
# 30-44 years 2634

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
df.agepreg.value_counts().sort_index()
# Out:
# 10.33     1
# 10.50     1
# 10.83     1
# 10.91     1
# 11.08     1
# 11.41     1
# 11.50     1
# 11.75     2
# 12.08     1
# 12.25     1
# 12.41     2
# 12.50     1
# 12.66     2
# 12.75     1
# 12.83     2
# 12.91     1
# 13.00     2
# 13.08     1
# 13.16     1
# 13.25     4
# 13.33     1
# 13.50     3
# 13.58     2
# 13.66     5
# 13.75     4
# 13.83     5
# 13.91     5
# 14.00     5
# 14.08     7
# 14.16    12
#          ..
# 40.50     6
# 40.58     4
# 40.66     4
# 40.75     2
# 40.83     4
# 40.91     4
# 41.00     2
# 41.08     2
# 41.16     2
# 41.25     6
# 41.33     1
# 41.41     2
# 41.58     4
# 41.75     3
# 41.83     1
# 41.91     4
# 42.08     2
# 42.16     1
# 42.25     1
# 42.33     1
# 42.41     1
# 42.50     2
# 42.58     2
# 42.75     2
# 43.00     3
# 43.16     1
# 43.25     4
# 43.58     3
# 43.91     1
# 44.08     1
# Name: agepreg, dtype: int64

# %% [markdown]
# In order to compare this data to the code book, the sums of each age group needs to be calculated. The code below calculates the sums of the number of women pregnant between the ages of 20 - 24

# %%
ages = df.agepreg.value_counts().sort_index()

# %%
sum(ages[0:19.99])
# Out:
# 3182

# %%
sum(ages[20:24.99])
# Out:
# 4246

# %%
sum(ages[25:29.99])
# Out:
# 3178

# %%
sum(ages[30:44.99])
# Out:
# 2635

# %% [markdown]
# The data above matches the codebook's data for the specified age ranges (below)!! The ages that were described as inapplicable could not be summed to validate.
#
# AGEPREG ( 284-287 )
#
# Variable Type : Preg recode
#
# Description : Age at pregnancy outcome (recode)
#
# value	label	 	Total
# .	INAPPLICABLE	 	352
# 0-1999	UNDER 20 YEARS	 	3182
# 2000-2499	20-24 YEARS	 	4246
# 2500-2999	25-29 YEARS	 	3178
# 3000-4499	30-44 YEARS	 	2635
#  	Total	 	13593

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
sorted_agepreg_counts = df.agepreg.value_counts().sort_index()

def compute_total_counts_for_subset(sorted_counts, start_slice, end_slice):
    total = 0
    for x in sorted_counts[start_slice:end_slice]:
        total += x
    return total

total_agepreg_counts_under20 = compute_total_counts_for_subset(sorted_agepreg_counts, 10.33, 19.91)
total_agepreg_counts_under25 = compute_total_counts_for_subset(sorted_agepreg_counts, 20.00, 24.91)
total_agepreg_counts_under30 = compute_total_counts_for_subset(sorted_agepreg_counts, 25.00, 29.91)
total_agepreg_counts_under45 = compute_total_counts_for_subset(sorted_agepreg_counts, 30.00, 44.91)
total_agepreg_counts = total_agepreg_counts_under20 + total_agepreg_counts_under25 + total_agepreg_counts_under30 + total_agepreg_counts_under45

print total_agepreg_counts_under20
print total_agepreg_counts_under25
print total_agepreg_counts_under30
print total_agepreg_counts_under45
print total_agepreg_counts

# This implementation was a bit time-consuming because of the extra investigation into the non-integer label values
# This function doesn't capture the inapplicable cases mentioned in the codebook
# Out:
# 3182
# 4246
# 3178
# 2635
# 13241

# %% [markdown]
# ## Question 2

# %% [markdown]
# Print value counts for <tt>agepreg</tt> and compare to results published in the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=A&subSec=8016&srtLabel=611935).
#
# Looking at this data, please remember my comments in the book about the obligation to approach data with consideration for the context and respect for the respondents.

# %%
under_20 = df.agepreg[df.agepreg < 20].count()
twenty_to_24 = df.agepreg[(df.agepreg >= 20) & (df.agepreg < 25)].count()
twentyfive_to_29 = df.agepreg[(df.agepreg >= 25) & (df.agepreg < 30)].count()
thirty_to_44 = df.agepreg[(df.agepreg >= 30) & (df.agepreg < 45)].count()
inapp_agepreg = df.caseid.count() - under_20 - twenty_to_24 - twentyfive_to_29 - thirty_to_44
inapp_agepreg, under_20, twenty_to_24, twentyfive_to_29, thirty_to_44
# Out:
# (352, 3182, 4246, 3178, 2635)

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb / 2.2
df.totalwgt_kg.mean()
# Out:
# 3.3025583898288029

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb/2.2
df.totalwgt_kg.mean()
# Out:
# 3.302558389828807

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592  # 0.453592 kg/lb
df.totalwgt_kg.mean()
# Out:
# 3.2956309433502984

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb / 2.20462
df.totalwgt_kg.mean()
# Out:
# 3.2956375509717635

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = (df.birthwgt_lb + df.birthwgt_oz/16.0) / 2.24 
df.totalwgt_kg.mean()
# Out:
# 3.2435841328675843

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb*0.453
df.totalwgt_kg.mean()
# Out:
# 3.2913296913033805

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb* 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
kilograms_per_pound = 0.453592
df['totalwgt_kg'] = df.totalwgt_lb * kilograms_per_pound

print df.totalwgt_kg.mean()
# Out:
# 3.29563094335

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb / 2.2
df.totalwgt_kg.mean()
# Out:
# 3.302558389828807

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = .4535*df.totalwgt_lb
df.totalwgt_kg.mean()
# Out:
# 3.294962505532179

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.45
df.totalwgt_kg.mean()
# Out:
# 3.2695328059304902

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb*0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb/2.204
df.totalwgt_kg.mean()
# Out:
# 3.296564635945284

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.birthwgt_lb / 2.2
df.totalwgt_kg.mean()
# Out:
# 3.1055101877428464

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb / 2.21
df.totalwgt_kg.mean()
# Out:
# 3.2876146867074061

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df['totalwgt_lb'].apply(lambda x: x*0.453592)
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = (df.birthwgt_lb + df.birthwgt_oz / 16.0) * 0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg']=df.totalwgt_lb/2.2046
print "Mean birth weight:", df.totalwgt_kg.mean(), "kg"
# Out:
# Mean birth weight: 3.2956674488 kg

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
lb_to_kg = 0.4536
df['totalwgt_kg']=df.totalwgt_lb*lb_to_kg
df.totalwgt_kg.mean()
# Out:
# 3.2956890683779663

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb/2.2046
df.totalwgt_kg.mean()
# Out:
# 3.29566744879946

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = (df.birthwgt_lb + (df.birthwgt_oz / 16)) / 2.24

df.totalwgt_kg.mean()
# Out:
# 3.2435841328675843

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb*0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
kgs_per_pound = 0.453 
df['totalwgt_kg'] = df.totalwgt_lb * kgs_per_pound

# %% [markdown]
# ## Question 3

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
df['totalwgt_kg'] = df.totalwgt_lb/2.24
df.totalwgt_kg.mean()
# Out:
# 3.2435841328675843

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print 'BFEEDWKS DATA'
print 'mean: ',df.bfeedwks.mean()
print
# print df.bfeedwks.value_counts().sort_index()
print '<1    ',len(df.bfeedwks[df.bfeedwks == 0])
print '1-52  ',len(df.bfeedwks[(df.bfeedwks >= 1) & (df.bfeedwks <= 52)])
print '53+   ',len(df.bfeedwks[(df.bfeedwks >= 53) & (df.bfeedwks <= 993)])
print 'still ',len(df.bfeedwks[df.bfeedwks == 994])
print 'never ',len(df.bfeedwks[df.bfeedwks == 995])
# Out:
# BFEEDWKS DATA
# mean:  465.207051763
#
# <1     65
# 1-52   3805
# 53+    516
# still  257
# never  3355

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
# Will look into the data behind the use of maternity leave
INAPPLICABLE = df.maternlv.isnull().sum()
notEmployed = (df.maternlv == 0).sum()
leaveDuring = (df.maternlv == 1).sum()
didNotTakeJob = (df.maternlv == 2).sum()
didNotTakeOffer = (df.maternlv == 3).sum()
didNotTakeOther = (df.maternlv == 4).sum()

print "INAPPLICABLE", INAPPLICABLE
print "NOT EMPLOYED DURING THIS PREGNANCY", notEmployed
print "TOOK MATERNITY LEAVE FROM JOB HELD DURING THIS PREGNANCY", leaveDuring
print "DID NOT TAKE - NOT NEEDED DUE TO JOB SCHEDULE OR SELF-EMPLOYMENT", didNotTakeJob
print "DID NOT TAKE - NOT OFFERED OR ALLOWED BY EMPLOYER", didNotTakeOffer
print "DID NOT TAKE - OTHER REASONS", didNotTakeOther
print "TOTAL", notEmployed + leaveDuring + didNotTakeJob +
# Out:
# INAPPLICABLE 10402
# NOT EMPLOYED DURING THIS PREGNANCY 1355
# TOOK MATERNITY LEAVE FROM JOB HELD DURING THIS PREGNANCY 1244
# DID NOT TAKE - NOT NEEDED DUE TO JOB SCHEDULE OR SELF-EMPLOYMENT 146
# DID NOT TAKE - NOT OFFERED OR ALLOWED BY EMPLOYER 93
# DID NOT TAKE - OTHER REASONS 353

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.pregend1.value_counts().sort_index()
# Out:
# 1    1921
# 2     120
# 3    1831
# 4     187
# 5    2015
# 6    7129
# 8      20
# 9      18
# Name: pregend1, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print 'Average weights in pounds:'
print 'MALE\t', df[df.babysex == 1].totalwgt_lb.mean()
print 'FEMALE\t', df[df.babysex == 2].totalwgt_lb.mean()
# Out:
# Average weights in pounds:
# MALE	7.41140948746
# FEMALE	7.11552604985

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
bfeedwks = df.bfeedwks
# filter out responses that did not specifically indicate a breast-feeding length. See documentation at tinyurl.com/zn9kw2d
bfeedwks_filtered = bfeedwks[(bfeedwks.notnull()) & (bfeedwks < 994)];
print "mean breastfeed weeks: " + str(bfeedwks_filtered.mean())
print "quartiles:"
print bfeedwks_filtered.quantile([.25, .5, .75])
# Out:
# mean breastfeed weeks: 28.9655722754
# quartiles:
# 0.25     9
# 0.50    22
# 0.75    43
# dtype: float64

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.wksgest.mean()
# Out:
# 30.01340893418129

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.learnprg.value_counts().sort_index()
df.learnprg.mean()
# Out:
# 5.2973840078973344

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.agepreg.mean()
# Out:
# 24.688151197038128

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.rmarout6.value_counts().sort_index()
df.learnprg.value_counts().sort_index()
df.learnprg.mean()
df.learnprg.median()
df.learnprg.std()
df.pncarewk.value_counts().sort_index()
df.pncarewk.mean()
df.pncarewk.median()
df.pncarewk.std()
# Out:
# 24.936835227466712

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print 'pregordr mean ', df.pregordr.mean()
df.pregordr.value_counts().sort_index()
# Out:
# pregordr mean  2.34915029795
# 1     5033
# 2     3766
# 3     2334
# 4     1224
# 5      613
# 6      308
# 7      158
# 8       78
# 9       38
# 10      17
# 11       8
# 12       5
# 13       3
# 14       3
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# Name: pregordr, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
inapplicable = len(df[np.isnan(df.fmarout5)])
married = len(df[df.fmarout5 == 1])
divorced = len(df[df.fmarout5 == 2])
widowed = len(df[df.fmarout5 == 3])
separated = len(df[df.fmarout5 == 4])
nevermarried = len(df[df.fmarout5 == 5])

print 'Inapplicable  ', inapplicable
print 'Married       ', married
print 'Divorced      ', divorced
print 'Widowed       ', widowed
print 'Separated     ', separated
print 'Never married ', nevermarried
print 'TOTAL         ', inapplicable + married + divorced + widowed + separated + nevermarried
# Out:
# Inapplicable   353
# Married        6409
# Divorced       735
# Widowed        31
# Separated      219
# Never married  5846
# TOTAL          13593

# %% [markdown]
# The values calculated above match the codebook results [here](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=PREG&section=&subSec=8016&srtLabel=611938) and we see that overwhelmingly married women and women that were never married are the majority of completed pregnancies.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %% [markdown]
# What percentage of pregnancies result in multiple births?

# %%
multipregs = df.multbrth.count()

percent = 100.0 * multipregs / len(df)
print "%.2f%%" % percent
# Out:
# 1.20%

# %% [markdown]
# What's the average number of live births per pregnancy?

# %%
print df.nbrnaliv.mean(), "babies"
# Out:
# 1.02241907262 babies

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.hpagelb.value_counts().sort_index()
# Out:
# 6       1
# 9       1
# 11      1
# 12      1
# 13      1
# 14      4
# 15     11
# 16     58
# 17    145
# 18    270
# 19    365
# 20    389
# 21    472
# 22    485
# 23    513
# 24    523
# 25    551
# 26    529
# 27    520
# 28    429
# 29    487
# 30    470
# 31    391
# 32    347
# 33    309
# 34    275
# 35    272
# 36    206
# 37    195
# 38    139
# 39    101
# 40    114
# 41     86
# 42     61
# 43     41
# 44     48
# 45     42
# 46     35
# 47     22
# 48     30
# 49     21
# 50     20
# 51      9
# 52      8
# 53      6
# 54      7
# 55      4
# 56      1
# 57      6
# 58      2
# 59      1
# 60      1
# 61      2
# 63      2
# 65      1
# 66      1
# 67      1
# 68      1
# dtype: int64

# %%
df.hpagelb.mean()
# Out:
# 27.848682754040293

# %%
df.hpagelb.median()
# Out:
# 27.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
#This is the age of the respondent at the time of the interview
df.ager.value_counts().sort_index()
# Out:
# 15      7
# 16     16
# 17     36
# 18     76
# 19    111
# 20    140
# 21    187
# 22    277
# 23    345
# 24    359
# 25    416
# 26    453
# 27    502
# 28    493
# 29    586
# 30    577
# 31    618
# 32    665
# 33    640
# 34    636
# 35    638
# 36    740
# 37    695
# 38    657
# 39    575
# 40    679
# 41    636
# 42    594
# 43    650
# 44    589
# Name: ager, dtype: int64

# %%
#The mean age of respondents is 33
df.ager.mean()
# Out:
# 33.470904141837714

# %%
#And the standard deviation in the age of respondents is 6.616
df.ager.std()
# Out:
# 6.715705627398683

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print '13 Weeks or Less: ', len(df[df.learnprg <= 13])
print '14 Weeks or Later: ', len(df[df.learnprg > 13])
print 'Average week aware of pregnancy: ', df.learnprg.mean()
print 'Latest week aware of pregnancy: ', df.learnprg.max()
# Out:
# 13 Weeks or Less:  3930
# 14 Weeks or Later:  122
# Average week aware of pregnancy:  5.2973840079
# Latest week aware of pregnancy:  39.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.multbrth.value_counts()
# Out:
# 1    129
# 5     34
# Name: multbrth, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.basewgt.value_counts().sort_index()

df.basewgt.mean()
# Out:
# 4216.27116440064

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
max(df.nbrnaliv)
# Out:
# 5.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.birthord.mean()
# Out:
# 1.8256449497157849

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print "MARRIED:", len(df[df.fmarout5 == 1])
print "DIVORCED:", len(df[df.fmarout5 == 2])
print "WIDOWED:", len(df[df.fmarout5 == 3])
print "SEPARATED:", len(df[df.fmarout5 == 4])
print "NEVER MARRIED:", len(df[df.fmarout5 == 5])
print "TOTAL:", len(df.fmarout5)
# Out:
# MARRIED: 6409
# DIVORCED: 735
# WIDOWED: 31
# SEPARATED: 219
# NEVER MARRIED: 5846
# TOTAL: 13593

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df[df.bfeedwks < 994].bfeedwks.mean() # Avg number of weeks breastfeeding, discounting those that never breastfed (code 995), and those currently breastfeeding (code 994)
# Out:
# 28.965572275421795

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.educat.value_counts().sort_index() # level of education in males
df.educat.mean() # average is slightly above high school (12 grade)
# Out:
# 12.66468035018024

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print "Use of maternity leave"
print "----------------------"
print "                                               inapplicable: " + str(len(df.maternlv) - len(df.maternlv[df.maternlv < 5]))
print "                              not employed during pregnancy: " + str(len(df.maternlv[df.maternlv == 0]))
print "                                        took leave from job: " + str(len(df.maternlv[df.maternlv == 1]))
print "did not take leave from job (job schedule or self-employed): " + str(len(df.maternlv[df.maternlv == 2]))
print "          did not take leave from job (not offered/allowed): " + str(len(df.maternlv[df.maternlv == 3]))
print "                did not take leave from job (other reasons): " + str(len(df.maternlv[df.maternlv == 4]))
# Out:
# Use of maternity leave
# ----------------------
#                                                inapplicable: 10402
#                               not employed during pregnancy: 1355
#                                         took leave from job: 1244
# did not take leave from job (job schedule or self-employed): 146
#           did not take leave from job (not offered/allowed): 93
#                 did not take leave from job (other reasons): 353

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
print "Live Birth       ", df.outcome.value_counts()[1]
print "Induced Abortion ", df.outcome.value_counts()[2]
print "Stillbirth       ", df.outcome.value_counts()[3]
print "Miscarriage      ", df.outcome.value_counts()[4]
print "Ectopic Pregnancy", df.outcome.value_counts()[5]
print "Current Pregnancy", df.outcome.value_counts()[6]
# print df.outcome.isnull().sum()
print "Total            ", df.outcome.value_counts().sum()
# Out:
# Live Birth        9148
# Induced Abortion  1862
# Stillbirth        120
# Miscarriage       1921
# Ectopic Pregnancy 190
# Current Pregnancy 352
# Total             13593

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.bfeedwks.value_counts().sort_index()
df.bfeedwks.mean()
# Out:
# 465.20705176294075

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.agecon.value_counts().sort_index()
df.agecon.mean()
# Out:
# 2420.70977709115

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.wksgest.mean()
# Out:
# 30.01340893418129

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
df.bfeedwks.value_counts().sort_index()
# Out:
# 0        65
# 1       122
# 2       182
# 3        95
# 4       288
# 5        33
# 6       138
# 7        18
# 8        45
# 9       329
# 10       24
# 11        5
# 12       14
# 13      438
# 14        4
# 15        2
# 16        1
# 17      323
# 18        6
# 19        1
# 22      175
# 24        2
# 26      413
# 30      180
# 31        1
# 32        2
# 33        1
# 35      191
# 36        1
# 39      180
#        ...
# 61       68
# 65       45
# 69       22
# 74       11
# 78       95
# 82        7
# 87       15
# 91        6
# 95       10
# 100       1
# 104      87
# 108       4
# 112       1
# 113       4
# 117       1
# 121       1
# 126       1
# 130      19
# 134       1
# 139       2
# 143       1
# 152       4
# 156      29
# 160       2
# 182       3
# 199       1
# 208       8
# 303       1
# 994     257
# 995    3355
# Name: bfeedwks, dtype: int64

# %%
df.bfeedwks.mean()
# Out:
# 465.20705176294075

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
# FMAROUT5 Description : Formal marital status at pregnancy outcome (recode)
# This is more of a categorical variable, so value counts are straightforward while a mean would be less obvious. 
# It would have to be the martial status of the mean age of the mothers -- a statistic based on another variable too.

sorted_fmarout5_counts = df.fmarout5.value_counts().sort_index()
print sorted_fmarout5_counts
# Out:
# 1    6409
# 2     735
# 3      31
# 4     219
# 5    5846
# Name: fmarout5, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# Look through the codebook and find a variable, other than the ones mentioned in the book, that you find interesting.  Compute values counts, means, or other statistics.

# %%
multbirth_age = df.agepreg[df.multbrth == 1].mean()
allbirth_age = df.agepreg.mean()
allbirth_age, multbirth_age
# Out:
# (24.688151197038128, 27.199534883720897)

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb>=9) & (live.birthwgt_lb<=95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)]) #95 is an aweful lot...
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb > 8) & (live.birthwgt_lb < 96)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb<=95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
print "Live births with birthweight between 9 and 95 pounds:", len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# Live births with birthweight between 9 and 95 pounds: 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 5

# %% [markdown]
# Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798

# %%
len(df.birthwgt_lb[(df.birthwgt_lb >= 9) & (df.birthwgt_lb <= 95)])
# Out:
# 798

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
fml = firsts.prglngth.mean()
oml = others.prglngth.mean()
(fml-oml)*7*24
# Out:
# 13.110260818628319

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firstMean = firsts.prglngth.mean()
othersMean = others.prglngth.mean()
print "FIRSTS mean time", firstMean
print "OTHERS mean time", othersMean

print "Difference of the means ", (firstMean - othersMean)*7*24
# Out:
# FIRSTS mean time 38.6009517335
# OTHERS mean time 38.5229144667
# Difference of the means  13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts.prglngth.mean()
# Out:
# 38.60095173351461

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print firsts.prglngth.mean(), 'weeks'
print others.prglngth.mean(), 'weeks'
print (firsts.prglngth.mean() - others.prglngth.mean()) * 168, 'hours difference'  # 168 hours/week
# Out:
# 38.6009517335 weeks
# 38.5229144667 weeks
# 13.1102608186 hours difference

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
first_prglngth = firsts.prglngth.mean()
others_prglngth = others.prglngth.mean()
diff = (first_prglngth - others_prglngth) * 7 * 24
print "First preg length: " + str(first_prglngth)
print "Other preg length: " + str(others_prglngth)
print "Difference in hours: " + str(diff)
# Out:
# First preg length: 38.6009517335
# Other preg length: 38.5229144667
# Difference in hours: 13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
(firsts.prglngth.mean() - others.prglngth.mean())*7*24
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
frst_prg = firsts.prglngth.mean()
othr_prg = others.prglngth.mean()
diff = (frst_prg - othr_prg)*(24*7)
diff
# Out:
# 13.110260818628319

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print firsts.prglngth.mean()
print others.prglngth.mean()
print (firsts.prglngth.mean() - others.prglngth.mean())* 7*24
# Out:
# 38.6009517335
# 38.5229144667
# 13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
f_prglngth = firsts.prglngth.mean()
o_prglngth = others.prglngth.mean()
diff = (f_prglngth - o_prglngth) * 7 * 24 #weeks to days to hours
print diff, "hours"
# Out:
# 13.1102608186 hours

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
abs(firsts.prglngth.mean() - others.prglngth.mean())*7*24
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts_prglngth = firsts.prglngth.mean()
print firsts_prglngth
# Out:
# 38.6009517335

# %%
others_prglngth = others.prglngth.mean()
print others_prglngth
# Out:
# 38.5229144667

# %%
diff = abs(firsts_prglngth - others_prglngth) #in weeks
print diff * 168 #168 hours / week so now in hours
# Out:
# 13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
hours_per_week = 7 * 24
firsts_prglngth_hrs = firsts.prglngth * hours_per_week
others_prglngth_hrs = others.prglngth * hours_per_week

firsts_prglngth_hrs.mean(), others_prglngth_hrs.mean()
# Out:
# (6484.9598912304555, 6471.849630411827)

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts.prglngth.mean()
# Out:
# 38.60095173351461

# %%
others.prglngth.mean()
# Out:
# 38.52291446673706

# %%
difference = firsts.prglngth.mean()-others.prglngth.mean()
difference
# Out:
# 0.07803726677754952

# %%
difference * 7 * 24
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firstlen = firsts.prglngth.mean()
firstlen
# Out:
# 38.60095173351461

# %%
otherlen = others.prglngth.mean()
otherlen
# Out:
# 38.52291446673706

# %%
#Compute the difference between first babies and other babies
#Then convert to hours
diff = (firstlen - otherlen) * 7 * 24
diff
# Out:
# 13.11026081862832

# %% [markdown]
# It appears that first babies tend to be born an average of 13 hours after second babies, so if they are late, they are not late by much.

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
fmean = firsts.prglngth.mean()
omean = others.prglngth.mean()

diff = (fmean - omean)*7*24
print 'First - subsequent pregnancy lengths: ', diff, 'hrs'
# Out:
# First - subsequent pregnancy lengths:  13.1102608186 hrs

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print firsts.prglngth.mean()

print others.prglngth.mean()

prglngth_mean_diff = (firsts.prglngth.mean() - others.prglngth.mean())*7*24 

print prglngth_mean_diff
# Out:
# 38.6009517335
# 38.5229144667
# 13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
(firsts.prglngth.mean()-others.prglngth.mean())*(24*7)
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firstlenmean = firsts.prglngth.mean()
otherlenmean = others.prglngth.mean()
diffweeks = firstlenmean - otherlenmean
diffhrs = diffweeks * 7 *24
diffhrs
# Out:
# 13.110260818628319

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts.prglngth.mean()
# Out:
# 38.600951733514613

# %%
others.prglngth.mean()
# Out:
# 38.522914466737063

# %%
print str((firsts.prglngth.mean() - others.prglngth.mean()) * 168) + " hours"
# Out:
# 13.1102608186 hours

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
first_avg = firsts.prglngth.mean()
other_avg = others.prglngth.mean()

first_avg - other_avg
# Out:
# 0.07803726677754952

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
first = df[df.birthord==1]
others = df[df.birthord>1]
difference_in_means = firsts.prglngth.mean() - others.prglngth.mean()
difference_in_means * 7 * 24 # it is normally in weeks, must convert it into hours
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print abs(firsts.prglngth.mean() - others.prglngth.mean()) * 7 * 24
# Out:
# 13.1102608186

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
print "Difference in mean weight:", (firsts.prglngth.mean()-others.prglngth.mean())*7*24, "hours"
# Out:
# Difference in mean weight: 13.1102608186 hours

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
lenf = firsts.prglngth.mean()
leno = others.prglngth.mean()
hrsinwk = 24*7
diff = (lenf - leno)*hrsinwk
lenf
leno
diff
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
mean_dif_w = firsts.prglngth.mean() - others.prglngth.mean()
mean_dif_h = mean_dif_w * 7 * 24
mean_dif_h
# Out:
# 13.11026081862832

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts.prglngth.mean()
# Out:
# 38.60095173351461

# %%
others.prglngth.mean()
# Out:
# 38.52291446673706

# %%
firsts.prglngth.mean() - others.prglngth.mean()
# Out:
# 0.07803726677754952

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
firsts_prglngth =  firsts.prglngth.mean() # weeks
others_prglngth =  others.prglngth.mean() # weeks
hours_per_week = 168 
firsts_others_prglngth_difference = abs(firsts.prglngth.mean() - others.prglngth.mean()) * hours_per_week # hours

print firsts_others_prglngth_difference, "hours"
# Out:
# 13.1102608186 hours

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compute the mean <tt>prglngth</tt> for first babies and others.  Compute the difference in means, expressed in hours.

# %%
flen = df.prglngth[df.birthord == 1].mean()
alen = df.prglngth[df.birthord > 1].mean()
(flen-alen)*7*24
# Out:
# 13.11026081862832

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# I found the reading to be interesting, but there were a few points I would like some guidance on. It seems like a lot of the stock programs do very important things but aren't really gone into in the most detail. Should we pursue those programs and try to understand them or is that not neccessary for the scope of this class?
# Additionally, warning us that this program only recognizes cells, and thereby the assets defined in said cells, when they have been manually run, would have mitigated some frustration.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# I think I generally understand this. Basically, there is an "ultimate dataset" called a data frame. This contains coded data which can be accessed through pre-defined label. Data types to deal with throughout this are the data frames, dictionary-like elements, collections, and series.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# No specific questions, but it would be nice to go over in class the best way to do each part (most efficient, readable, etc.)

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# I have no questions, this was relatively straightforward

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# I don't have any right now!

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# <p>
#  For the base weight variable the numbers match information in the database and I assume that in this data a large amount of data is incorrect due to the large amount of variance but am not sure what the cutoffs are in order to do validation on the data set.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# I am confused about recodes, as comparing numbers computed from the whole data set to the data set itself seems very redundant. Do we take a small sample of the entire raw data to calculate the recodes?

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %%
# Are clarifying questions required? For another class I worked on, we were assumed to always have something to say. For me, that is not always the case.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# None

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# * More discussion on the tradeoff for oversampling different groups in a study: At a high level I understand the benefits, but am wondering what is considered when designing to oversample and tradeoffs considered (larger variety of results and potential insights, resources for the survey implementation, additional efforts to recruit, etc).

# %% [markdown]
# ## Clarifying Questions
#
# Use this space to ask questions regarding the content covered in the reading. These questions should be restricted to helping you better understand the material. For questions that push beyond what is in the reading, use the next answer field. If you don't have a fully formed question, but are generally having a difficult time with a topic, you can indicate that here as well.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# This chapter mentioned that the NSFG intentionally oversampled Hispanics, African-Americans, and teenagers. How can this be addressed if you want to look at a statistically-correct distribution over the entire population?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# I'm wondering how typical it is to find datasets in the format here. I've done a fair amount of stuff with aid-data resources, and they are much less sophisticated than this...we're talking CSVs as the most hi-tech translation of the data.
#
# Just as a general note, it was cool to do something with population data, and it would be great to do more peoples analysis in the future. An element that was not explored here was doing cross comparisons (correlations for example), which I'm sure will come later. Significance would also be cool to learn more about.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# No questions yet

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# The work on cleaning data at least as far as was done in the first chapter primarily relied on understanding how the survey results and the recodes were reported. For example, Allen takes codes used to report certain conditions for birth weight and changes them to NaNs. What would you do if where you are getting your data from is not well-documented enough for you to know whether what you interpret are logical values or codes? Do you take a guess at what seems reasonable and what isn't and how do you report this in regards to the validity of your conclusions?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# What is the difference between section B of the Raw Variables and Section E in the codebook? I'm just curious about what context I'm missing for the different variables.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# This is something that I'm a little unclear on in general, but I'm wondering what sorts of data science scenarios it's benficial/the "right" answer is to use a graph, and what questions are better answered using summary statistics/numbers. Is it always helpful to visualize? Are there times when it's better/acceptable not to?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# <p>
#     The book mentioned basic data checking but are there methods to do checking on the processed results after data validation for results or is that completely up to human interpretation?
# </p>

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# I am curious if whether we will always be given data sets in such convenient form to use in this class, or whether we will build data sets ourselves.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %%
# Are the blanks in the assignment specifically chosen. It seemed that a lot was already filled in.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# How would you deal with situations where the data doesn't accurately represent the population, e.g., certain demographics are more represented than others? Are there tools for analyzing or cleaning the data?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# I know it's only chapter one so I don't have too many questions, but the one I was wondering about as I was doing this assignment was how to figure out the value of the calculations.  Like, we could calculate so many values from this dataset, how do we know what is important?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# How do you validate data if no published results exist for comparison?

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# * What are some other recommended ways to validate data?
# * In addition to validation: pitfalls that happen when one first works with a dataset?
# * Pitfalls that happen when one works with a dataset for a long time? I am guessing that good documentation helps a lot with preventing these pitfalls.

# %% [markdown]
# ## Enrichment Questions
#
# Use this space to ask any questions that go beyond (but are related to) the material presented in this reading. Perhaps there is a particular topic you'd like to see covered in more depth. Perhaps you'd like to know how to use a library in a way that wasn't show in the reading. One way to think about this is what additional topics would you want covered in the next class (or addressed in a followup e-mail to the class). I'm a little fuzzy on what stuff will likely go here, so we'll see how things evolve.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# I liked having pandas.pydata.org to read more on the different possible methods for a dataframe

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# I didn't find any for this exercise.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# None

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.

# %% [markdown]
# ## Additional Resources / Explorations
#
# If you found any useful resources, or tried some useful exercises that you'd like to report please do so here. Let us know what you did, what you learned, and how others can replicate it.
