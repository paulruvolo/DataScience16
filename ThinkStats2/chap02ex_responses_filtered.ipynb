# %% [markdown]
# ## Question 1

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
numfmhh_hist = thinkstats2.Hist(resp.numfmhh)
thinkplot.Hist(numfmhh_hist, label='# in household')
thinkplot.Show()

# %% [markdown]
# ## Question 1

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
hist = thinkstats2.Hist(resp.numfmhh)
thinkplot.Hist(hist, label='numfmhh')
thinkplot.Show(xlabel='Family Members', ylabel='Frequency',title='Number of Family Members in the Household')

# %% [markdown]
# Two is the mode number of people in the respondent's household, and this distribution is fairly symmetrical for values between zero and four.  The tail extends more to the right because a family size cannot be less than zero.

# %% [markdown]
# ## Question 1

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
import matplotlib.pyplot as plt
# Cool, there's a panas DataFrame.hist() function that lets us go straight from a historgram
# This function also defaults to 10 bins, and I want one per value. 
resp.hist("numfmhh", bins = 8)
plt.xlabel("Number of people in respondent's household")
plt.ylabel("Number of responses")
plt.title("Distribution of the Household Size")

# %% [markdown]
# ## Question 1

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
import seaborn as sns
thinkplot.Hist(thinkstats2.Hist(resp.numfmhh), label = 'numfmhh')
thinkplot.Show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
parity_hist = thinkstats2.Hist(resp.parity)
thinkplot.Hist(parity_hist, label='amount of children')
thinkplot.Show()

# %% [markdown]
# This shows that the largest group was that of individuals who did not have any children. Next, 2 children seemed most common, with 1 trailing behind. A sharp drop off shows that 3 or more children was less common.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
hist = thinkstats2.Hist(resp.parity)
thinkplot.Hist(hist, label='parity')
thinkplot.Show(xlabel='Births', ylabel='Frequency',title='Number of Live Births')

# %% [markdown]
# The data's mode is 0, meaning that there are large number of missing data or unborn babies. If excluding 0, the mode is at 2 babies.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
hist = thinkstats2.Hist(resp.parity)
thinkplot.Hist(hist, label='parity')
thinkplot.Show()

# %%
print 'The majority of respondents have had no children. After that, the general is between 1-5, with a very few between 6-10'
# Out:
# The majority of respondents have had no children. After that, the general is between 1-5, with a very few between 6-10

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
hist = thinkstats2.Hist(resp.parity)
thinkplot.Hist(hist, label='parity')
thinkplot.Show(xlabel='children resp. has borne', ylabel='frequency')

"""Describe Distribution: Mode=0, Asymmetric, Tail Extends Right. It is most common that the respondent has borne no children. As the # of children born increases, frequency generally decreases, though the frequencies of 1 and 2 are about the same."""
# Out:
# 'Describe Distribution: Mode=0, Asymmetric, Tail Extends Right. It is most common that the respondent has borne no children. As the # of children born increases, frequency generally decreases, though the frequencies of 1 and 2 are about the same.'

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
hist_parity = thinkstats2.Hist(resp.parity)
thinkplot.Hist(hist_parity, label = 'parity')
thinkplot.Show(xlabel = 'number of children respondent has borne', ylabel = 'frequency')

# %% [markdown]
# The mode for this distribution is 0 children. Around 3250 women resported that they had given birth to zero children, the frequency is greater for the value of 0 than any other value. The distribution does not look like a normall Gaussian distribution. This is because a left tail does not exist, but the right tail very much so extends to around 10 children.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %% [markdown]
# I would describe this distribution as very skewed to the left.  There seems to be a significant mode at 0 and the right tail drops off very quickly once we get to 4 or 5.  It's also very clustered - not a very large spread.

# %% [markdown]
# The distribution has one main cluster and a central tendency at around 0. The distribution drops off significantly for higher numbers of children. and there are a couple outliers (22 children and 16 children).

# %% [markdown]
# Zero is the mode number of children the respondent has borne, having roughly twice the number of occurences as the next most common response.  It decreases from there in an exponential-esque way, except for an increase from one child to two children, with the extreme values of 16 and 22 children having one response each.

# %% [markdown]
# ### Distribution Interpretation
# As the distribution of the respondents' parity shows, 0 is more common than other values with an average value of about 1.2. The distribution has a tail that extends to the right while most respondents falls between 0 child and 5 child. The standard deviation is 1.39, which means we should expect deviation of 1 to 2 children to be common. Although we can barely see from the histograph, there is one case for 22 children and one for 16 children. In this case, we need some domain knowledge to understand the outliers.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
resp.hist("parity", bins = 22)
plt.xlabel("Number of children the respondent has borne")
plt.ylabel("Number of responses")
plt.title("Distribution of the Respondents' Parity")

# %% [markdown]
# It seems that the vast majority of respondents have borne between 0-2 children previously, and that there are basically no respondents who have had more than 5 or 6 chilren. This distributions is certainly not uniform, and looks a litle more like a gaussian or normal distribution, except only half of it. There is no tail to the left. This is not surprising, because it would not make sense for a respondent to have borne negative children.

# %% [markdown]
# <p>
#        The distribution is not a normal distribution most values fall within the range of 0-5. The distribution is like half a bell curve with the data centered at 0.
# </p>

# %% [markdown]
# ## Question 3

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
largest = thinkstats2.Hist.Largest(parity_hist)
print largest
# Out:
# [(22, 1), (16, 1), (10, 3), (9, 2), (8, 8), (7, 15), (6, 29), (5, 95), (4, 309), (3, 828)]

# %% [markdown]
# ## Question 3

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
# Returns the 3 largest values in parity
hist.Largest(3)
# Out:
# [(22, 1), (16, 1), (10, 3)]

# %% [markdown]
# ## Question 3

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
for babies, freq in hist.Largest(10):
        print "Number of Babies:", babies, "Frequency: ",freq
# Out:
# Number of Babies: 22 Frequency:  1
# Number of Babies: 16 Frequency:  1
# Number of Babies: 10 Frequency:  3
# Number of Babies: 9 Frequency:  2
# Number of Babies: 8 Frequency:  8
# Number of Babies: 7 Frequency:  15
# Number of Babies: 6 Frequency:  29
# Number of Babies: 5 Frequency:  95
# Number of Babies: 4 Frequency:  309
# Number of Babies: 3 Frequency:  828

# %% [markdown]
# ## Question 3

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
hist=thinkstats2.Hist(resp.parity)
print '#Borne', 'Freq'
for parity, freq in hist.Largest(3): #look at the potential outliers
    print parity, '    ', freq

#see that 22 is a decided outlier, as well as 16. Without doing a 
#stronger outlier analysis, hard to tell whether 10 actually fits 
#within the distribution
# Out:
# #Borne Freq
# 22      1
# 16      1
# 10      3

# %% [markdown]
# This shows the 5 largest parity values.  The two largest are 22 and 16, both of which have a single data point.  This isn't even visible on the histogram, so I would append my previous remarks to say that you could also describe the distribution as having outliers at 22 and 16.

# %% [markdown]
# As mentioned above, there was 1 response each of 16 and 22 children.  Additionally, there were 3 responses of 10 children, 2 responses of 9 children, and 8 responses of 8 children.

# %%
# Here, I want to get better at pandas/numpy so I'm not going to use the Hist.Largest function
# This will return the largest values and the row number of the first occurrence of this value

print ("number of children | number of respondents")
print(resp.parity.value_counts().sort_index()[-5:])
# Out:
# number of children | number of respondents
# 8     8
# 9     2
# 10    3
# 16    1
# 22    1
# Name: parity, dtype: int64

# %% [markdown]
# I'm a little surprised by someone haivng 22 or 16 children. I certainly would believe that these could be entries that were wrongly inputted, but I also don't know tons about the number of children people tend to have/can have. Since the other, larger  counts each have more than one response, I'm less inclined to believe that these are mistakes.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %%
richparity = thinkstats2.Hist(resp.parity[resp.totincr > 8])
thinkplot.Hist(richparity, label='parity for high income respondents')
thinkplot.Show()

# %% [markdown]
# ## Question 4

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %%
high_income = resp.parity[resp.totincr == 14] #from the codebook, implies income of over $75,000
above_median = resp.parity[resp.totincr >= 12] #for the sake of comparison, used google to find

hist = thinkstats2.Hist(high_income)
thinkplot.Hist(hist,label='parity of highest income')
thinkplot.Show(xlabel='Num Borne', ylabel='Frequency')

hist2 = thinkstats2.Hist(above_median)
thinkplot.Hist(hist2,label='parity for above average income')
thinkplot.Show(xlabel='Num Borne', ylabel='Frequency')

#turns out these distributions are extremely similar

# %% [markdown]
# Looking at just the high income respondents, the same general trends are seen.  Zero children is the most common response, there is an increase from one child to two children, and it decreases significantly from there.  The extreme values are lower: one response each of 7 and 8 children.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %%
totincr = resp.totincr
highest_income = totincr.max()
print "The highest income value label is ", highest_income, " which represents $75,000 OR MORE"
hist = thinkstats2.Hist(totincr)
large_income = []
for pair in hist.Largest()[:4]:
    large_income.append(pair[0])
threshold = large_income[-1]
large_income_parity_data = resp.parity[totincr > threshold]
hist = thinkstats2.Hist(large_income_parity_data)
thinkplot.Hist(hist, label = "high income respondents' parity")
thinkplot.Show()
# Out:
# The highest income value label is  14  which represents $75,000 OR MORE

# %% [markdown]
# ## Question 4

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %% [markdown]
# To do this, I first want to find the respondents with high income. Then, I'll filter the respondents based on a threshold income. Then, I'll find the distribution of parity for just those participants.
#
# After looking at the [Codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=MALE&section=R&subSec=7958&srtLabel=609776), it appears that this field is a recode, and the highest income participants have income code of 14. So, to find the highest income participants, I'll use only participants with totincr 14.

# %%
highIncomeResp = resp[resp.totincr == 14]
highIncomeResp.hist("parity", bins = 8)
plt.xlabel("Number of children the respondent has borne")
plt.ylabel("Number of responses")
plt.title("Distribution of the Respondents' Parity")

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
# I'm defining largest parities as higher than 5
highpar_hist = thinkstats2.Hist(resp[resp.parity >= 5].totincr)
thinkplot.Hist(highpar_hist, label='earnings for highest children count')

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
hist.Largest(3)
# Out:
# [(8, 1), (7, 1), (5, 5)]

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
b = hist.Largest(5)

print ['highest parity for high income respondents: ' + str(b[0][0])]
# Out:
# ['highest parity for high income respondents: 8']

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
print ('num_kids', 'freq')
for num_kids, freq in hist_high_income.Largest(5):
    print (num_kids, freq)
# Out:
# ('num_kids', 'freq')
# (8, 1)
# (7, 1)
# (5, 5)
# (4, 19)
# (3, 123)

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
print hi_income.parity.value_counts()
# Out:
# 0    499
# 2    263
# 1    222
# 3    120
# 4     19
# 5      5
# 8      1
# 7      1
# Name: parity, dtype: int64

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
import math

# Compute for all others
notHighInc = resp[resp.totincr != resp.totincr.max()]

# Get the low and high income means from parity dist.
meanHigh = highInc.parity.mean()
meanLow = notHighInc.parity.mean()

# Calculate diff
diff = meanHigh-meanLow

# Print result - negative result implied that high income mothers have 0.174 (approx at 3 significant digits) fewer 
# babies, compared to notHigh income mothers
print math.fabs(diff)
# Out:
# 0.173713744701

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
print "Rich", rich.parity.mean()
print "Others", others.parity.mean()
# Out:
# Rich 1.04547316673
# Others 1.30661284121

# %% [markdown]
# The difference between the parity of high income respondents and the parity of other income respondents is very small. This means that people with high income do not necessarily have more children than people with average income.

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
target = resp[resp.totincr==12]
others = resp[resp.totincr < 12]
print "Rich people's average parirty: " + str(target.parity.mean())
print "Normal people's average parirty: " + str(others.parity.mean())
# Out:
# Rich people's average parirty: 1.04103343465
# Normal people's average parirty: 1.30661284121

# %% [markdown]
# For high income respondents, the mean parity was 1.076 children.  For others, it was 1.250 children.  It appears that those with high income have fewer children, but the difference is fairly small in the grand scheme of things.

# %% [markdown]
# ## Question 6

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
high = resp.loc[resp['totincr'] == 14]
medhi = resp.loc[resp['totincr'] == 13]
lowhi = resp.loc[resp['totincr'] == 2]
low = resp.loc[resp['totincr'] == 1]
print('income 75k or more: ' + str(high.parity.mean()))
print('income 64k - 74k: ' + str(medhi.parity.mean()))
print('income 5k - 7.5k: ' + str(lowhi.parity.mean()))
print('income < 5k: ' + str(low.parity.mean()))
# Out:
# income 75k or more: 1.0758620689655172
# income 64k - 74k: 0.9935794542536116
# income 5k - 7.5k: 1.5016611295681064
# income < 5k: 1.2876254180602007

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
# investigating income > 10th group and age correlation
ageinc_hist = thinkstats2.Hist(resp[resp.totincr > 10].age_r)
thinkplot.Hist(ageinc_hist, label='income')
thinkplot.Show()

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
# I was very interested in exploring how higher education and race are connected. I initially 
# looked at the number of black people with Master's degrees and then compared that to the number of white respondents.  
blackMasters = resp[(resp.rscreenrace == 4) & (resp.hieduc == 13 )]
blackT = resp[(resp.rscreenrace == 4)]

whiteMasters = resp[(resp.rscreenrace == 5) & (resp.hieduc == 13 )]
whiteT = resp[(resp.rscreenrace == 5)]

percWhiteMaster = float(len(whiteMasters))/len(whiteT)
percBlackMaster = float(len(blackMasters))/len(blackT)

print "Only ", percBlackMaster*100, "% of black respondents got a master's degree. On the other hand, ", percWhiteMaster*100, "% of white respondents got a master's degree, double the value of black respondents."
# Out:
# Only  2.5641025641 % of black respondents got a master's degree. On the other hand,  4.11211506546 % of white respondents got a master's degree, double the value of black respondents.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
"""bc12pay11 looks at how a method of birth control or a prescription for a method was paid.
1	INSURANCE 
2	CO-PAYMENT, OR OUT-OF-POCKET PAYMENT
3	MEDICAID
4	NO PAYMENT REQUIRED
5	SOME OTHER WAY
"""
hist1 = thinkstats2.Hist(rich.bc12pay11)
hist2 = thinkstats2.Hist(others.bc12pay11)

width = 0.40
thinkplot.PrePlot(2)
thinkplot.Hist(hist1, align='right', width=width, label='rich')
thinkplot.Hist(hist2, align='left', width=width, label='others')
thinkplot.Show(xlabel='Values', ylabel='Frequency')

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
# Seeing the difference in parity between all respondents and those living with no father figure at age 14
noffparity = thinkstats2.Hist(resp.parity[resp.lvsit14m == 3])
parity = thinkstats2.Hist(resp.parity)
thinkplot.Hist(parity, label='parity')
thinkplot.Show()
thinkplot.Hist(noffparity, label='no ff parity')
thinkplot.Show()

# Difference in parity mean:
print '   No FF mean parity:',resp.parity[resp.lvsit14m == 3].mean()
print 'everyone mean parity:',resp.parity.mean()
# Out:
#    No FF mean parity: 1.33526011561
# everyone mean parity: 1.22321078111

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hist = thinkstats2.Hist(resp.rscreenrace)
thinkplot.Hist(hist, label='distribution of race')
thinkplot.Show()

# %%
print '.: inapplicable, 1-3: other race groups, 4: black or african american, 5: white'
# Out:
# .: inapplicable, 1-3: other race groups, 4: black or african american, 5: white

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
working_parity = resp[resp.laborfor < 5].parity
non_working_parity = resp[resp.laborfor >= 5].parity

mean_working_parity = working_parity.mean()
mean_non_working_parity = non_working_parity.mean()

print 'Mean Parity Working Women= '
print mean_working_parity
print '  '
print 'Mean Parity Unemployed Women'
print mean_non_working_parity

print ' '
print 'Working'

work_hist = thinkstats2.Hist(working_parity)
thinkplot.Hist(work_hist, label='parity')
thinkplot.Show()

print 'Not Employed'
non_work_hist = thinkstats2.Hist(non_working_parity)
thinkplot.Hist(non_work_hist, label='parity')
thinkplot.Show()
# Out:
# Mean Parity Working Women=
# 1.14694694695
#
# Mean Parity Unemployed Women
# 1.3670694864
#
# Working
# Not Employed

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
resp[resp.age_r >40].prevhusb.value_counts()
# Out:
# 0    446
# 1    285
# 2     82
# 3     13
# Name: prevhusb, dtype: int64

# %% [markdown]
# The numbers mean the women's previous husband count. Fractionally, 0.53995157385 women of the total women in this report over the age of 40 have never been married before, this is roughly half. Interestingly the numbers decrease as the number of husbands increase.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hist = thinkstats2.Hist(resp.numfmhh)
thinkplot.Hist(hist, label='num_people_in_house')
thinkplot.Show(xlabel="number of family member in household", ylabel="number of respondents")
print "average number of family members in house: ", resp.numfmhh.mean()
# Out:
# average number of family members in house:  2.2325003271

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
#I investigate age of first menarche in relationship to household income
#then compare first menarche with number of sexual partners

def compare(main_data, filter_for_data, bound):
    hist = thinkstats2.Hist(main_data) #get a sense of the distribution
    
    upper = main_data[filter_for_data >= bound]
    lower = main_data[filter_for_data < bound]
    
    upper_hist = thinkstats2.Hist(upper)
    lower_hist = thinkstats2.Hist(lower)
    
    upper_mean = upper.mean()
    lower_mean = lower.mean()
    diff = abs(upper_mean-lower_mean)
    
    return hist, upper_hist, lower_hist, upper_mean, lower_mean, diff
    

print 'MENARCHE AGE AND INCOME'
valid_menarche_ages = resp.menarche[resp.menarche <= 95] #get rid of special codes

hist, high_hist, other_hist, hi_mean, oi_mean, diff = compare(valid_menarche_ages, resp.totincr, 14)
thinkplot.Hist(hist,label='Age of menarche')
thinkplot.Show(xlabel='Year', ylabel='Frequency')

width = 0.4
thinkplot.PrePlot(2)
thinkplot.Hist(high_hist, align='right', width=width, label='Highest Income')
thinkplot.Hist(other_hist, align='left', width=width, label='Other Income')
thinkplot.Show(xlabel='Year', ylabel='Frequency')

print 'High Income', hi_mean
print 'Low Income', oi_mean
print 'Difference', diff
print '     '

print 'MENARCHE AGE AND SEXUAL PARTNERS'

mv_hist, many_hist, few_hist, many_mean, few_mean, difference = compare(valid_menarche_ages, resp.lifeprt, 5)

width = 0.4
thinkplot.PrePlot(2)
thinkplot.Hist(many_hist, align='right', width=width, label='Five or More Partners')
thinkplot.Hist(few_hist, align='left', width=width, label='Fewer than Five Partners')
thinkplot.Show(xlabel='Year', ylabel='Frequency')

print 'Five or More', many_mean
print 'Fewer than Five', few_mean
print 'Difference', difference

#this is interesting to look at because of the amount of conversation about the age of menarche and social factors
#like overall income (and highest educational status), number of sexual encounters, etc. This data shows that there
#might be something evident in the data, but confounding factors like age at time of the survey, would need to be
#accounted for in order to make sense of the information
# Out:
# MENARCHE AGE AND INCOME
# High Income 12.6424242424
# Low Income 12.5146398141
# Difference 0.127784428327
#
# MENARCHE AGE AND SEXUAL PARTNERS
# Five or More 12.4937647455
# Fewer than Five 12.5988909427
# Difference 0.105126197164

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
#Looking at parity as categorized by primary vs secondary education

high_school = resp[resp.educat < 13]
secondary = resp[resp.educat >= 13]

hist1 = thinkstats2.Hist(high_school.parity)
hist2 = thinkstats2.Hist(secondary.parity)
thinkplot.Hist(hist1, label='high school parity')
thinkplot.Hist(hist2, label='secondary parity')

thinkplot.Show()

print ['mean parity for high school respondents: ' + str(high_school.parity.mean())]
print ['mean parity for secondary respondents: ' + str(secondary.parity.mean())]
# Out:
# ['mean parity for high school respondents: 1.39020618557']
# ['mean parity for secondary respondents: 1.05102311985']

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
# I will investigate different 
# labor force groups the respondent was a part of

# Create Histogram item for labor force
hist_laborfor = thinkstats2.Hist(resp.laborfor)
thinkplot.Hist(hist_laborfor, label='Labor Force')

"""
Key:
1	WORKING FULL-TIME	 	2763
2	WORKING PART-TIME	 	756
3	WORKING-TEMP ILL/ETC	 	168
4	WORKING-MATERNITY OR FAMILY LEAVE	 	7
5	NOT WORKING BUT LOOKING FOR WORK	 	302
6	SCHOOL	 	437
7	KEEPING HOUSE	 	222
8	CARING FOR FAMILY	 	34
9	OTHER	 	239
"""

# isolate the full time work group to a new hist item
thinkplot.Show(title='Labor Force', xlabel='Social Status',ylabel='freq')
fulltime_work = resp[resp.laborfor == 1]

# Graph parity for full time working respondents
hist_fulltime_work_parity = thinkstats2.Hist(fulltime_work.parity, label='fulltime work parity')
thinkplot.Hist(hist_fulltime_work_parity)
thinkplot.Show(title='Fulltime work parity',xlabel='parity',ylabel='freq')

# Finding mean of parity for both full time and other 
other_work = resp[resp.laborfor != 1]
mean_fulltime_work = fulltime_work.parity.mean()
mean_other_work = other_work.parity.mean()
print "Fulltime Work Parity Mean:", mean_fulltime_work
print "Other Work Parity Mean:", mean_other_work
# Out:
# Fulltime Work Parity Mean: 1.18201154664
# Other Work Parity Mean: 1.25436580882

# %% [markdown]
# By examining this, we see that the data corresponds with my predicted trend. People who work full time jobs seem to have less children as they do not have the time or money to afford them, compared to others.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
print "High Income Age of First having sex: " + str(incomeHigh.agefstsx.mean())
print "Not High Income Age of First having sex: " + str(notIncomeHigh.agefstsx.mean())
# Out:
# High Income Age of First having sex: 18.6744186047
# Not High Income Age of First having sex: 17.8793253347

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hist = thinkstats2.Hist(resp.religion)
thinkplot.Hist(hist, label="relgion")
thinkplot.Show()
# 1 = no religion
# 2 = catholic
# 3 = protestant
# 4 = other

# %%
thinkplot.Hist(thinkstats2.Hist(resp.parity[resp.religion == 1]), label="parity of no religion resp")
thinkplot.Show()
thinkplot.Hist(thinkstats2.Hist(resp.parity[resp.religion == 2]), label="parity of catholic resp")
thinkplot.Show()
thinkplot.Hist(thinkstats2.Hist(resp.parity[resp.religion == 3]), label="parity of protestant resp")
thinkplot.Show()
thinkplot.Hist(thinkstats2.Hist(resp.parity[resp.religion == 4]), label="parity of other relig resp")
thinkplot.Show()

# %%
print "mean parity of no religion resp:", resp.parity[resp.religion == 1].mean()
print "mean parity of catholic resp:", resp.parity[resp.religion == 2].mean()
print "mean parity of protestant resp:", resp.parity[resp.religion == 3].mean()
print "mean parity of other religion resp:", resp.parity[resp.religion == 4].mean()
# Out:
# mean parity of no religion resp: 0.993693693694
# mean parity of catholic resp: 1.28836797877
# mean parity of protestant resp: 1.2896389325
# mean parity of other religion resp: 0.897777777778

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
"Compare the mean education level between high income respondents and others."
target = resp[resp.totincr >= 12]
others = resp[resp.totincr < 12]
print "Rich people's average education level:" + str(target.higrade.mean())
print "Normal people's average education level: " + str(others.higrade.mean())
# Out:
# Rich people's average education level(the higher the better): 14.4748054076
# Normal people's average education level: 12.7579777009

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
no_college_degree_hispanic = resp[(resp.hieduc <= 10) & (resp.hispanic == 1)]
college_degree_hispanic = resp[(resp.hieduc > 10) & (resp.hispanic == 1)]

no_college_degree_nonhispanic = resp[(resp.hieduc <= 10) & (resp.hispanic == 2)]
college_degree_nonhispanic = resp[(resp.hieduc > 10) & (resp.hispanic == 2)]

percent_hispanic_college_degree = (float(len(college_degree_hispanic))/(len(college_degree_hispanic) + len(no_college_degree_hispanic)))*100
percent_nonhispanic_college_degree = (float(len(college_degree_nonhispanic))/(len(college_degree_nonhispanic) + len(no_college_degree_nonhispanic)))*100
print percent_hispanic_college_degree, "% of hispanic respondents have college degrees."
print percent_nonhispanic_college_degree, "% of non-hispanic respondents have college degrees. Wow."
# Out:
# 15.796098175 % of hispanic respondents have college degrees.
# 31.2851007598 % of non-hispanic respondents have college degrees. Wow.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %% [markdown]
# Below is a plot of income levels of the respondents who received public assistance in 2001.

# %%
resp_receivedassist = resp[resp.pubassis == 1]
hist = thinkstats2.Hist(resp_receivedassist.totincr)
thinkplot.Hist(hist, label='income')
thinkplot.show()

# %% [markdown]
# ...and this is an income histogram for people who did not receive public assistance.

# %%
resp_notreceivedassist = resp[resp.pubassis == 2]
hist = thinkstats2.Hist(resp_notreceivedassist.totincr)
thinkplot.Hist(hist, label='income')
thinkplot.show()

# %% [markdown]
# The two distributions are completely different - many lower-income households received public assistance while many higher-income households did not need public assistance. Another interesting thing to note is that people in the \$15,000 to \$19,999 income bracked received more public assistance than those who earn less than that amount of money.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
print 'mean interview length:', resp.intvlngth.mean(), 'minutes'

print 'mean number of children 1st husband had from previous relationship:', 
print resp.numkdshx[resp.numkdshx != 99].mean(),  # 99 codes for "don't know"
print 'children'
# Out:
# mean interview length: 82.7555576533 minutes
# mean number of children 1st husband had from previous relationship: 1.80706921944 children

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
resp_household_5_more = resp[resp.numfmhh >= 5]
resp_household_5_less = resp[resp.numfmhh < 5]

hist_household_5_more = thinkstats2.Hist(resp_household_5_more.parity)
hist_household_5_less = thinkstats2.Hist(resp_household_5_less.parity)

thinkplot.Hist(hist_household_5_more, label='parity of respondents more than 5 household')
thinkplot.Show(xlabel='value', ylabel='frequency')

print "average parity for respondents with more than 5 houses", resp_household_5_more.parity.mean()
print "average parity for respondents with less than 5 houses", resp_household_5_less.parity.mean()
# Out:
# average parity for respondents with more than 5 houses 2.55945419103
# average parity for respondents with less than 5 houses 1.1270687237

# %% [markdown]
# ### Histogram Interpretion
# The parity of respondents more than 5 household has two modes, with 0 to be the most common value and 4 children to be the second most common value. The rest of the graph seems to cluster around value 4 but it is hardly bell-shaped. The tail extends more to the right than to the left. There is an outlier of 22 in the graph. Again, we need domain knowledge in order to interprete that outlier.
#
# Compared to the distribution of the general parity, the average parity for respondents with more than 5 houses is 2.56 while the general average is 1.12. Respondents with more than 5 houses tend to have more children than the others on average.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hist = thinkstats2.Hist(resp.age_a)
thinkplot.Hist(hist, label = "ages")
thinkplot.Show()

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
lowinc = resp.loc[resp['totincr'] == 1]

print 'lowest income mean age at first birth: ' + str(lowinc.age_r.mean())
print 'highest income mean age at first birth: ' + str(highinc.age_r.mean())

lowincomehist = thinkstats2.Hist(lowinc.age_r)
thinkplot.Hist(lowincomehist, label='lowest income', width=0.45)
print thinkplot.Show(xlabel='age at first birth', ylabel='number of respondents')
# Out:
# lowest income mean age at first birth: 26.6454849498
# highest income mean age at first birth: 31.4172413793
# None

# %% [markdown]
# I first calculated the mean age of the mother at her first birth for the respondents in the lowest income bracket and for those in the highest bracket. There is about a five year difference, with the mean age of the mothers in the highest bracket being 31.4 and the lowest being 26.6. The graph shows that more women in the lowest income brackets are having babies when they are younger, with a peak at 20 years old.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
print "high income on own before age 18: %f" % (sum(hi_income.onown18==1) / float(len(hi_income)))
print "low income on own before age 18:  %f" % (sum(other.onown18==1) / float(len(other)))
# Out:
# high income on own before age 18: 0.158407
# low income on own before age 18:  0.252111

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
yes_to_babies = resp[resp.rwant == 1] #wants another baby
no_to_babies = resp[resp.rwant == 5] #do not want another baby
yes_hist = thinkstats2.Hist(yes_to_babies.age_r)
no_hist = thinkstats2.Hist(no_to_babies.age_r)

thinkplot.PrePlot(2)
thinkplot.Hist(yes_hist, align = 'right', label = 'yes', width = 0.45) #displayed on the left!!
thinkplot.Hist(no_hist, align = 'left', label = 'no', width = 0.45, color = 'r') #displayed on the right!!
thinkplot.Show(title = 'Do you want to have baby at some time in the future?', xlabel = 'Respondent' + "'" + 's age', axis = [14, 45, 0, 300])

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %% [markdown]
# I'm interested in how whether or not the respondent has a degree affects the number of children they have had, so I'm going to be doing similar analysis as above, but with degree status as the differentiator, not income. I would expect that there are similar trends as with income, where respondents with degrees tend to have fewer children.

# %%
import numpy as np

#First split up the dataframe as those with degrees and those without degrees
withDegrees = resp[resp.havedeg == 1]
withoutDegrees = resp[resp.havedeg == 5]

#Histogram code borrowed from: http://stackoverflow.com/questions/25539195/multiple-histograms-in-pandas
fig, ax = plt.subplots()


withoutDegreeHeights, withoutDegreeBins = np.histogram(withoutDegrees['parity'], bins = 22, density = 1)
withDegreeHeights, withDegreeBins = np.histogram(withDegrees['parity'], bins = withoutDegreeBins, density = 1)

width = (withDegreeBins[1] - withDegreeBins[0])/2.5

ax.bar(withDegreeBins[:-1], withDegreeHeights, width=width, facecolor='cornflowerblue')
ax.bar(withoutDegreeBins[:-1]+width, withoutDegreeHeights, width=width, facecolor='seagreen')


ax.legend(['With Degrees', 'Without Degrees'])
ax.set_xlabel('Number of children borne by respondent')
ax.set_ylabel('Percentage of Respondents')
ax.set_title('Distribution of Parity based on Degree Status')

# %% [markdown]
# Although I'm not too sure about this, it does not seem that degree status has a huge effect on how many children someone has had. (To do this analysis, I used a normalized version of the histogram, so that I had percentage of women, instead of just the pure count.) In other words, it seems that income is a much better predictor of the number of children someone will have than whether or not that person has a degree. Interesting.

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
otherIncHist = thinkstats2.Hist(otherIncParity, label = 'Other income parity')

width= 0.4
thinkplot.PrePlot(2)
thinkplot.Hist(parIncHist, align ='right',width=width)
thinkplot.Hist(otherIncHist, align = 'left', width=width)
thinkplot.Show(xlabel='# of children', ylabel='freq')
#this looks off. Possibly mis-calculated other category

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
hi_vc = high_income.hadsex.value_counts()
other_vc = others.hadsex.value_counts()

hi_vc = hi_vc.apply(lambda x: float(x) / hi_vc.sum())
other_vc = other_vc.apply(lambda x: float(x) / other_vc.sum())

print "Proportion of high income respondents who have had sex: " + str(hi_vc[1])
print "Proportion of other respondents who have had sex: " + str(other_vc[1])
print

hi_vc = high_income.insuranc.value_counts().sort_index()
other_vc = others.insuranc.value_counts().sort_index()

hi_vc = hi_vc.apply(lambda x: float(x) / hi_vc.sum())
other_vc = other_vc.apply(lambda x: float(x) / other_vc.sum())

print "Healthcare status proportions for high-income:"

print hi_vc

print
print "for others:"

print other_vc
# Out:
# Proportion of high income respondents who have had sex: 0.889655172414
# Proportion of other respondents who have had sex: 0.887397809656
#
# Healthcare status proportions for high-income:
# 1    0.037931
# 2    0.916379
# 3    0.019828
# 4    0.025862
# Name: insuranc, dtype: float64
#
# for others:
# 1    0.194663
# 2    0.581984
# 3    0.147771
# 4    0.075582
# Name: insuranc, dtype: float64

# %% [markdown]
# ## Question 7

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
new_data = resp[resp.agemomb1 == 1]

hist = thinkstats2.Hist(new_data.parity)
thinkplot.Hist(hist, label = 'parity of teenage mothers')
thinkplot.Show()

hist2 = thinkstats2.Hist(new_data.con1mar1)
thinkplot.Hist(hist, label = 'time between conception and marriage for teenage mothers')
thinkplot.Show(xlabel = '# of months', ylabel = 'frequency')

max_value = resp['totincr'].max()

highest_income_respondents = resp[resp.totincr == max_value]
hist = thinkstats2.Hist(highest_income_respondents.con1mar1)
thinkplot.Hist(hist, label = 'time between conception and marriage for mothers with the highest incomes')
thinkplot.Config(xlim = [0,200], ylim = [0,50])
thinkplot.Show(xlabel = '# of months', ylabel = 'frequency')

# %% [markdown]
# <p>
# From the histograms of parity of teenage mothers compared to all mothers it seems that teenage mothers have on average slightly more children with the center of the distribution being somewhere around 2-3.
# When comparing marriage and time of conceptions for teenage mothers to those of high income mothers: the majority get married before the baby is born for teenage while it drastically ranges for high income mothers
# </p>

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Exercise 4
#
# Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen’s d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?

# %%
import nsfg
df = nsfg.ReadFemPreg()

# %% [markdown]
# With data imports out of the way, now we can actually look at baby weights and birth order.

# %%
live = df[df.outcome == 1]

first = live[live.birthord == 1]
others = live[live.birthord != 1]

print first.totalwgt_lb.mean(), ',', others.totalwgt_lb.mean()
# Out:
# 7.20109443044 , 7.32585561497

# %%
from math import sqrt
from math import pow

diff = others.totalwgt_lb.mean() - first.totalwgt_lb.mean()
sd = sqrt((pow(first.totalwgt_lb.var(), 2) + pow(others.totalwgt_lb.var(), 2)) / 2)

cohen = diff / sd
print cohen
# Out:
# 0.0629708817548

# %%
import nsfg

def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean()

    var1 = group1.var()
    var2 = group2.var()
    n1, n2 = len(group1), len(group2)

    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    d = diff / math.sqrt(pooled_var)
    return d

sett = nsfg.ReadFemPreg()
first = sett[sett.birthord == 1]
others = sett[sett.birthord != 1]

totalwgt = CohenEffectSize(first.totalwgt_lb, others.totalwgt_lb)
prglngth = CohenEffectSize(first.prglngth, others.prglngth)

print "Cohen's d on total_wgt: ", totalwgt
print "Cohen's d on preg_lngth: ", prglngth
# Out:
# Cohen's d on total_wgt:  -0.0889364117772
# Cohen's d on preg_lngth:  1.09300834336

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Exercise 4
#
# Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen’s d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?

# %%
import nsfg
import math 

df = nsfg.ReadFemPreg()
first = df[df.birthord == 1]
others = df[df.birthord != 1]

def CohenEffectSize(first, others):
    diff = first.mean() - others.mean()
    
    var1 = first.var()
    var2 = others.var()
    n1, n2 = len(first), len(others)
    
    pooled_var = (n1*var1 + n2*var2) / (n1 + n2)
    d = diff / math.sqrt(pooled_var)
    
    return math.fabs(d)

CohenEffectSize(first.totalwgt_lb, others.totalwgt_lb)
# Out:
# 0.08893641177719079

# %%
##From this it appears that first children tend to weigh less than others.

# %%
CohenEffectSize(first.prglngth, others.prglngth)
# Out:
# 1.0930083433621403

# %%
##From this it seems that first children tend to be born before other children, although the numbers seem pretty close to each other.

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Exercise 4
#
# Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen’s d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?

# %%
import nsfg
pregs = nsfg.ReadFemPreg()

# %%
firsts = pregs[pregs.birthord == 1]
others = pregs[pregs.birthord != 1]

# %%
first_weights = firsts.totalwgt_lb.value_counts()
other_weights = others.totalwgt_lb.value_counts()
print "mean total weight of first born babies:", first_weights.mean()
print "mean total weight of other born babies:", other_weights.mean()

# %%
def Cohen(one, two): 
    diff = one.mean() - two.mean()
    
    var1 = one.var()
    var2 = two.var()
    n1, n2 = len(one), len(two)
    
    pooled_var = (n1 *var1 + n2*var2)/(n1 + n2)
    d = diff / math.sqrt(pooled_var)
    return math.fabs(d)

print Cohen( first_weights, other_weights)

# %% [markdown]
# The difference between the two total weights is 0.08667245291558709 standard deviations away from each other. This number is incredibly small. This means that the total weight of the first born child is not too different from the weight of the other children, their weights are relatively close together when born.

# %%
firsts_length = firsts.prglngth
others_length = others.prglngth
print "mean pregnancy length of first born babies:", firsts_length.mean()
print "mean pregnancy length weight of other born babies:", others_length.mean()

# %%
Cohen(firsts_length, others_length)

# %% [markdown]
# According to these calculations, women are pregnant with their first born children longer than they are pregnant with other children by a significant amount. Oddly enough this was not the conclusion Allen came to in the book. With this data, women are pregnant around 13.4297099034 weeks longer with their first born than with any of the later children. Compared to total weights, there is a significant difference in pregnancy length between firsts and others than there was when comparing total weights. Having a medium Cohen value means that the strength of this phenomenon is medium, meaning that it has a medium effect or medium correlation betweeen the two pregnancy lengths

# %% [markdown]
# The the effect of being the first baby on birth weight is about 3 times as large, but in the opposite direction, compared to the effect of brith order on pregnancy weight.

# %%
# cohen's d = mean(x1) - mean(x2) / s where s = pooled std
print "d =", thinkstats2.CohenEffectSize(firsts, others)
# Out:
# d = -0.0889364117772

# %% [markdown]
# The difference in pregnancy length as Cohen's d is 0.029 standard deviations, or almost neglible.  Here, d = 0.0889 (the negative is irrelevant, depends on which input is first), which is a larger effect than the difference in pregnancy lengths, but still very tiny

# %%
print cohens_d(firsts.prglngth, others.prglngth)
# Out:
# 0.0288790446544

# %% [markdown]
# Pregnancies for firstborns are 0.029 standard deviations longer than for other children. This is even more negligible.

# %% [markdown]
# ### Interpretation
# Cohen's D of -0.089 is statistically small and therefore there is not a significant difference between first babies and other babies. Compared to the Cohen's D's value for pregnancy length (as given in the book, is 0.029) of the two groups, it is a little bit larger, but still not large enough to be considered as a significant difference.

# %% [markdown]
# ### Exercise 4
#
# Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen’s d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?

# %%
preg = nsfg.ReadFemPreg()

live = preg[preg.outcome == 1]

firsts = live[live.birthord == 1]
others = live[live.birthord != 1]

print 'First baby mean weight: ' + str(firsts.totalwgt_lb.mean())
print 'Other babies mean weight: ' + str(others.totalwgt_lb.mean())

def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean()

    var1 = group1.var()
    var2 = group2.var()
    n1, n2 = len(group1), len(group2)

    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    d = diff / math.sqrt(pooled_var)
    return d

print "Cohen's d: " + str(CohenEffectSize(firsts.totalwgt_lb, others.totalwgt_lb))
# Out:
# First baby mean weight: 7.20109443044
# Other babies mean weight: 7.32585561497
# Cohen's d: -0.0886729270726

# %% [markdown]
# Babies born first are on average slightly lighter than others, but not enough to really make any sciencey decisions.

# %%
firstsMeanWt = firsts.totalwgt_lb.mean()
othersMeanWt = others.totalwgt_lb.mean()
firstsMeanWt,othersMeanWt
# Out:
# (7.201094430437772, 7.325855614973262)

# %% [markdown]
# So, it looks like first babies tend to be a little lighter than other babies
#
# Now, let's calculate the Cohen's _d_

# %%
import math
diff = firstsMeanWt - othersMeanWt

firstsVarWt = firsts.totalwgt_lb.var()
othersVarWt = others.totalwgt_lb.var()

pooledVarWt = (firstCount*firstsVarWt + othersCount*othersVarWt)/(firstCount + othersCount)

d = diff/math.sqrt(pooledVarWt)
print ("Cohen's d: " + str(d))
# Out:
# Cohen's d: -0.0886729270726

# %% [markdown]
# I'm honestly not sure how significiant this is, but it's more significant than the example in the book. That's acutally something I have a question about. At what threshold is something sigificant as far as effect size goes? Is there a generally accepted threshold?

# %% [markdown]
# <p>
#     The Cohen d for total weight vs pregnancy length of firstborns vs non firstborns are both very small with a smaller standard deviation difference in total weight between firstborn and nonfirstborn births
# </p>
