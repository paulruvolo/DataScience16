# %% [markdown]
# ## An Exploration of the Bike Share Kaggle Dataset
#
# In this document, I will show you how to do some basic exploration and cleaning of the kaggle Bike share dataset.  The data is checked into the repository under `DataScience16/datasets/kaggle_bikeshare_train.csv`.  The code here relies on you running this notebook from the `DataScience16/exercises` directory.

# %% [markdown]
# First, we will read the data into a Pandas dataframe.  The NSFG class from ThinkStats reading is really just a thin wrapper around `pandas.read_csv`.

# %%
import pandas as pd

data = pd.read_csv('../../datasets/kaggle_bikeshare_train.csv')

print data.head()
print data.describe()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81          0       3          13     16
# 1        80          0       8          32     40
# 2        80          0       5          27     32
# 3        75          0       3          10     13
# 4        75          0       0           1      1
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %% [markdown]
# ### Checking for Missing values
#
# When you first work with a dataset, it's always a good idea to check for missing values.  To do this we will use the pandas isnull() function.  Keep in mind that this is just one method of determining whether or not data is missing.  It will only tell part of the story.  What are some other ways of figuring out if there are missing values?

# %%
data.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# ### Validating our Recodes
#
# The next thing to do is to make sure we understand some of recodes in the data.  We know that we are trying to predict count which is presumably a combination of casual and registered.  Let's check this hypothesis.  Note: this is more about checking our own understanding rather than checking to validity of the data (since we can be reasonably confident that it is correct).  However, you could imagine this would be a good unit test for recodes that you created yourself.  In fact, this unit test would serve as a guide for anyone else reading your code as to what exactly the recode means.

# %% [markdown]
# You may have noticed we used the dictionary notation to lookup `count` whereas we used the dot-notation to lookup registered and casual.  The reason for this is that is a method of the DataFrame class, and thus it is ambiguous which we are referring to (the column or the method).  Let's learn more about this by printing out the type of `data.registered`, `data['registered']`, `data['count']`, and `data.count`.

# %% [markdown]
# ### Exploring Basic Properties of the Data
#
# Next, we will look at each of the variables in some more detail.

# %%
pd.options.display.max_rows = 500
print data.casual.value_counts().sort_index()
print data.registered.value_counts().sort_index()
# Out:
# 0      986
# 1      667
# 2      487
# 3      438
# 4      354
# 5      332
# 6      269
# 7      250
# 8      250
# 9      230
# 10     213
# 11     193
# 12     190
# 13     146
# 14     137
# 15     146
# 16     141
# 17     134
# 18     128
# 19     141
# 20     120
# 21     116
# 22     104
# 23      87
# 24      95
# 25     103
# 26      91
# 27     124
# 28     105
# 29      99
# 30      87
# 31     105
# 32      64
# 33     100
# 34      70
# 35      67
# 36      78
# 37      61
# 38      65
# 39      69
# 40      76
# 41      56
# 42      71
# 43      47
# 44      60
# 45      47
# 46      47
# 47      51
# 48      59
# 49      54
# 50      52
# 51      57
# 52      41
# 53      54
# 54      56
# 55      56
# 56      51
# 57      45
# 58      46
# 59      50
# 60      37
# 61      53
# 62      33
# 63      45
# 64      33
# 65      35
# 66      42
# 67      31
# 68      39
# 69      45
# 70      40
# 71      37
# 72      35
# 73      31
# 74      35
# 75      38
# 76      29
# 77      27
# 78      38
# 79      32
# 80      28
# 81      22
# 82      29
# 83      26
# 84      22
# 85      30
# 86      28
# 87      16
# 88      32
# 89      25
# 90      21
# That's pretty hard to get much out of.  Let's see if we can do better by merging the two series together into a dataframe.

# %%
pd.concat([data.casual.value_counts(), data.registered.value_counts()], axis=1)
# Out:
#      casual  registered
# 0       986          15
# 1       667         135
# 2       487         150
# 3       438         195
# 4       354         190
# 5       332         177
# 6       269         155
# 7       250         126
# 8       250         114
# 9       230         114
# 10      213          72
# 11      193          87
# 12      190          57
# 13      146          52
# 14      137          67
# 15      146          54
# 16      141          56
# 17      134          46
# 18      128          51
# 19      141          66
# 20      120          53
# 21      116          52
# 22      104          59
# 23       87          61
# 24       95          51
# 25      103          40
# 26       91          47
# 27      124          43
# 28      105          46
# 29       99          39
# 30       87          49
# 31      105          44
# 32       64          32
# 33      100          38
# 34       70          43
# 35       67          31
# 36       78          28
# 37       61          30
# 38       65          36
# 39       69          39
# 40       76          31
# 41       56          38
# 42       71          26
# 43       47          44
# 44       60          31
# 45       47          28
# 46       47          33
# 47       51          34
# 48       59          45
# 49       54          42
# 50       52          37
# 51       57          30
# 52       41          27
# 53       54          39
# 54       56          33
# 55       56          40
# 56       51          28
# 57       45          33
# 58       46          35
# 59       50          29
# 60       37          28
# 61       53          34
# 62       33          34
# 63       45          32
# 64       33          42
# 65       35          30
# 66       42          33
# 67       31          29
# 68       39          35
# 69       45          26
# 70       40          33
# 71       37          30
# 72       35          36
# 73       31          30
# 74       35          34
# 75       38          23
# 76       29          33
# 77       27          28
# 78       38          32
# 79       32          30
# 80       28          34
# 81       22          35
# 82       29          29
# 83       26          34
# 84       22          33
# 85       30          30
# 86       28          40
# 87       16          29
# 88       32          40
# 89       25          34
# 90       21          26
# 91       28          31
# 92       13          34
# 93       12          29
# 94       18          34
# 95       19          48
# 96       18          35
# 97       19          30
# 98       19          32
# 99       15          37
# 100      18          31
# 101      18          27
# 102      21          34
# 103      14          33
# 104      15          41
# 105      12          30
# 106       8          31
# 107      13          33
# 108      22          41
# 109      14          27
# 110      11          35
# 111      17          34
# 112      15          37
# 113      16          20
# 114       9          33
# 115      11          42
# 116      10          37
# 117      10          23
# 118       7          32
# 119      11          35
# 120      17          37
# 121      11          32
# 122       9          24
# 123       9          28
# 124       7          26
# 125       9          22
# 126       4          32
# 127       7          36
# 128      16          32
# 129      10          23
# 130       6          41
# 131       8          22
# 132       9          28
# 133       8          32
# 134       8          35
# 135       5          27
# 136       2          27
# 137       4          36
# 138       8          25
# 139      10          32
# 140       4          17
# 141       7          38
# 142      10          41
# 143       7          23
# 144       8          38
# 145       8          23
# 146       5          24
# 147       7          27
# 148      12          34
# 149       5          24
# 150       8          35
# 151       5          25
# 152       3          27
# 153       7          29
# 154       3          26
# 155       6          32
# 156       7          37
# 157       2          26
# 158       4          31
# 159       5          23
# 160       3          20
# 161       8          34
# 162       3          33
# 163       4          32
# 164      10          22
# 165       4          22
# 166       6          25
# 167       6          22
# 168       7          37
# 169       4          30
# 170       7          29
# 773     NaN           1
# 775     NaN           1
# 778     NaN           1
# 779     NaN           1
# 780     NaN           1
# 781     NaN           1
# 782     NaN           1
# 786     NaN           1
# 787     NaN           2
# 788     NaN           1
# 789     NaN           1
# 790     NaN           1
# 791     NaN           1
# 794     NaN           1
# 800     NaN           1
# 802     NaN           1
# 803     NaN           1
# 806     NaN           1
# 807     NaN           1
# 811     NaN           1
# 812     NaN           2
# 833     NaN           1
# 839     NaN           1
# 857     NaN           2
# 886     NaN           1
#
# [731 rows x 2 columns]

# %% [markdown]
# That's much more revealing!  What sorts of patterns does that reveal?  How does the behavior of the two user populations differ?
#
# They say a picture is worth a thousand words (or a thousand numbers).  Let's create a visual representation of the counts above.  This is called a histogram.  We will do this using Seaborn, but you will have a chance to learn how to do it using ThinkStats and ThinkPlot in the reading for next time.

# %%
import seaborn as sbs
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

sbs.distplot(data.casual, kde=False, bins=np.arange(0,1000,10))
sbs.distplot(data.registered, kde=False, bins=np.arange(0,1000,10))
sbs.plt.show()

n, bins, patches = plt.hist(data.casual, bins=np.arange(0,1000,10))
n, bins, patches = plt.hist(data.registered, bins=np.arange(0,1000,10), stacked=True)

plt.show()

# %% [markdown]
# ## Investigating Relationship Between Ridership and Other Factors
#
# We will investigate some different methods for determining how the value of one factor affects the value of another.  As a first example, let's determine the effect of whether or not it is a working day has on the ridership for both casual and registered riders.

# %%
working_day = data.workingday == 1
print "Mean ridership for casual riders on a working day", data[working_day].casual.mean()
print "Mean ridership for registered riders on a working day", data[working_day].registered.mean()

print "Mean ridership for casual riders on a non-working day", data[~working_day].casual.mean()
print "Mean ridership for registered riders on a non-working day", data[~working_day].registered.mean()
# Out:
# Mean ridership for casual riders on a working day 25.1076632488
# Mean ridership for registered riders on a working day 167.90420939
# Mean ridership for casual riders on a non-working day 59.3082901554
# Mean ridership for registered riders on a non-working day 129.198330455

# %% [markdown]
# Next, we'll use the `groupby` operation to do this in an even more convenient fashion.

# %% [markdown]
# Another cool use of `groupby` is that you can specify multiple columns to essentially get conjunctions.  Let's test the interaction between the `season` column and the `holiday` columns.

# %% [markdown]
# ## Recodes
#
# Next, we will parse through the datetime field to create some recodes that will allow us to access various fields datetime.  A typical entry in the datetime columns looks like this: `2011-04-05 13:00:00`.  Next, we will create a function that converts this string into a tuple of integers in the format year, month, day, hour.

# %%
# Out:
# TestResults(failed=0, attempted=1)

# %% [markdown]
# Next, we will apply our function to create some new columns in our data frame.

# %% [markdown]
# As a final step, we will use our recodes to create some time series plots.

# %%
#sbs.tsplot(data.groupby('hour').registered.mean(), color='r', condition='registered')
#sbs.tsplot(data.groupby('hour').casual.mean(), condition='casual')

plt.plot(data.groupby('hour').registered.mean())
plt.plot(data.groupby('hour').casual.mean())
plt.show()

# %% [markdown]
# ### Go Play!
#
# Explore some interesting facets of the data.  Think carefully about whether the results are best communicated in tabular format, raw text, or graphically.
